# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:07<00:00, 107.41it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:02<00:00, 158.84it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:06<00:00, 132.58it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:07<00:00, 111.83it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:00<00:00, 171.05it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:00<00:00, 190.32it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:00<00:00, 196.96it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:00<00:00, 144.86it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: Baseline CNN

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)))
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 4
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Classification Head
    model.add(layers.Flatten())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(512, activation='relu'))

    # Output layer
    model.add(layers.Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.01)))

    # Compile with Adam optimizer
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"baseline_cnn_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr]
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.3034 - loss: 6.3313
# Epoch 1: val_accuracy improved from None to 0.41667, saving model to baseline_cnn_fold_1.keras
#
# Epoch 1: finished saving model to baseline_cnn_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 26s 268ms/step - accuracy: 0.3295 - loss: 3.4602 - val_accuracy: 0.4167 - val_loss: 1.4350 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.4014 - loss: 1.4889
# Epoch 2: val_accuracy did not improve from 0.41667
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.3968 - loss: 1.4645 - val_accuracy: 0.3844 - val_loss: 1.3983 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.4248 - loss: 1.4011
# Epoch 3: val_accuracy improved from 0.41667 to 0.44898, saving model to baseline_cnn_fold_1.keras
#
# Epoch 3: finished saving model to baseline_cnn_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.4295 - loss: 1.3850 - val_accuracy: 0.4490 - val_loss: 1.3589 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4675 - loss: 1.3329
# Epoch 4: val_accuracy improved from 0.44898 to 0.46599, saving model to baseline_cnn_fold_1.keras
#
# Epoch 4: finished saving model to baseline_cnn_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.4662 - loss: 1.3362 - val_accuracy: 0.4660 - val_loss: 1.2760 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4841 - loss: 1.2935
# Epoch 5: val_accuracy improved from 0.46599 to 0.59864, saving model to baseline_cnn_fold_1.keras
#
# Epoch 5: finished saving model to baseline_cnn_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 195ms/step - accuracy: 0.4930 - loss: 1.2899 - val_accuracy: 0.5986 - val_loss: 1.1931 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4820 - loss: 1.2925
# Epoch 6: val_accuracy did not improve from 0.59864
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5015 - loss: 1.2815 - val_accuracy: 0.5663 - val_loss: 1.2227 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5049 - loss: 1.2477
# Epoch 7: val_accuracy improved from 0.59864 to 0.62585, saving model to baseline_cnn_fold_1.keras
#
# Epoch 7: finished saving model to baseline_cnn_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 195ms/step - accuracy: 0.5096 - loss: 1.2440 - val_accuracy: 0.6259 - val_loss: 1.1363 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5208 - loss: 1.2156
# Epoch 8: val_accuracy did not improve from 0.62585
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.5283 - loss: 1.2233 - val_accuracy: 0.5799 - val_loss: 1.1762 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5278 - loss: 1.2125
# Epoch 9: val_accuracy did not improve from 0.62585
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.5321 - loss: 1.2107 - val_accuracy: 0.5680 - val_loss: 1.2024 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6161 - loss: 1.1328
# Epoch 10: val_accuracy did not improve from 0.62585
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.6015 - loss: 1.1415 - val_accuracy: 0.5170 - val_loss: 1.2962 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6019 - loss: 1.1436
# Epoch 11: val_accuracy did not improve from 0.62585
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.5849 - loss: 1.1449 - val_accuracy: 0.5340 - val_loss: 1.2956 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5921 - loss: 1.1361
# Epoch 12: val_accuracy did not improve from 0.62585
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.5934 - loss: 1.1266 - val_accuracy: 0.5493 - val_loss: 1.2567 - learning_rate: 1.0000e-06
# Score for fold 1: loss of 1.2567; compile_metrics of 54.93%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.3043 - loss: 6.8589
# Epoch 1: val_accuracy improved from None to 0.53571, saving model to baseline_cnn_fold_2.keras
#
# Epoch 1: finished saving model to baseline_cnn_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - accuracy: 0.3376 - loss: 3.7988 - val_accuracy: 0.5357 - val_loss: 1.2750 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.3609 - loss: 1.5730
# Epoch 2: val_accuracy improved from 0.53571 to 0.56973, saving model to baseline_cnn_fold_2.keras
#
# Epoch 2: finished saving model to baseline_cnn_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 195ms/step - accuracy: 0.3716 - loss: 1.5530 - val_accuracy: 0.5697 - val_loss: 1.2253 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.4077 - loss: 1.4438
# Epoch 3: val_accuracy did not improve from 0.56973
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.4232 - loss: 1.4208 - val_accuracy: 0.5578 - val_loss: 1.2274 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4561 - loss: 1.3700
# Epoch 4: val_accuracy improved from 0.56973 to 0.62415, saving model to baseline_cnn_fold_2.keras
#
# Epoch 4: finished saving model to baseline_cnn_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4334 - loss: 1.3737 - val_accuracy: 0.6241 - val_loss: 1.1642 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.4549 - loss: 1.3532
# Epoch 5: val_accuracy improved from 0.62415 to 0.63265, saving model to baseline_cnn_fold_2.keras
#
# Epoch 5: finished saving model to baseline_cnn_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4598 - loss: 1.3392 - val_accuracy: 0.6327 - val_loss: 1.1383 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4379 - loss: 1.3297
# Epoch 6: val_accuracy did not improve from 0.63265
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.4615 - loss: 1.3218 - val_accuracy: 0.6088 - val_loss: 1.1299 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4913 - loss: 1.3024
# Epoch 7: val_accuracy improved from 0.63265 to 0.66667, saving model to baseline_cnn_fold_2.keras
#
# Epoch 7: finished saving model to baseline_cnn_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4951 - loss: 1.2924 - val_accuracy: 0.6667 - val_loss: 1.1233 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4789 - loss: 1.2862
# Epoch 8: val_accuracy did not improve from 0.66667
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.4994 - loss: 1.2705 - val_accuracy: 0.6122 - val_loss: 1.1627 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5197 - loss: 1.2479
# Epoch 9: val_accuracy did not improve from 0.66667
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5304 - loss: 1.2302 - val_accuracy: 0.6378 - val_loss: 1.0806 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5447 - loss: 1.2048
# Epoch 10: val_accuracy did not improve from 0.66667
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5462 - loss: 1.2011 - val_accuracy: 0.6173 - val_loss: 1.0975 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5604 - loss: 1.2179
# Epoch 11: val_accuracy did not improve from 0.66667
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.5560 - loss: 1.2029 - val_accuracy: 0.6310 - val_loss: 1.0672 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5670 - loss: 1.1795
# Epoch 12: val_accuracy did not improve from 0.66667
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.5696 - loss: 1.1820 - val_accuracy: 0.6327 - val_loss: 1.0644 - learning_rate: 1.0000e-06
# Score for fold 2: loss of 1.0644; compile_metrics of 63.27%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.2915 - loss: 8.9585
# Epoch 1: val_accuracy improved from None to 0.42589, saving model to baseline_cnn_fold_3.keras
#
# Epoch 1: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 23s 256ms/step - accuracy: 0.3170 - loss: 4.7963 - val_accuracy: 0.4259 - val_loss: 1.4042 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.3336 - loss: 1.5929
# Epoch 2: val_accuracy improved from 0.42589 to 0.48722, saving model to baseline_cnn_fold_3.keras
#
# Epoch 2: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.3447 - loss: 1.5493 - val_accuracy: 0.4872 - val_loss: 1.3288 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.3907 - loss: 1.4204
# Epoch 3: val_accuracy improved from 0.48722 to 0.50426, saving model to baseline_cnn_fold_3.keras
#
# Epoch 3: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.4021 - loss: 1.4120 - val_accuracy: 0.5043 - val_loss: 1.2707 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4564 - loss: 1.3484
# Epoch 4: val_accuracy improved from 0.50426 to 0.53152, saving model to baseline_cnn_fold_3.keras
#
# Epoch 4: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.4323 - loss: 1.3553 - val_accuracy: 0.5315 - val_loss: 1.2453 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4487 - loss: 1.3300
# Epoch 5: val_accuracy improved from 0.53152 to 0.53492, saving model to baseline_cnn_fold_3.keras
#
# Epoch 5: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4438 - loss: 1.3412 - val_accuracy: 0.5349 - val_loss: 1.2238 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4609 - loss: 1.3255
# Epoch 6: val_accuracy improved from 0.53492 to 0.54344, saving model to baseline_cnn_fold_3.keras
#
# Epoch 6: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4723 - loss: 1.3027 - val_accuracy: 0.5434 - val_loss: 1.1988 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4730 - loss: 1.2988
# Epoch 7: val_accuracy improved from 0.54344 to 0.55196, saving model to baseline_cnn_fold_3.keras
#
# Epoch 7: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.4834 - loss: 1.2870 - val_accuracy: 0.5520 - val_loss: 1.1899 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5218 - loss: 1.2512
# Epoch 8: val_accuracy improved from 0.55196 to 0.58773, saving model to baseline_cnn_fold_3.keras
#
# Epoch 8: finished saving model to baseline_cnn_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5217 - loss: 1.2501 - val_accuracy: 0.5877 - val_loss: 1.1663 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.5419 - loss: 1.2258
# Epoch 9: val_accuracy did not improve from 0.58773
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.5353 - loss: 1.2195 - val_accuracy: 0.5792 - val_loss: 1.1768 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5488 - loss: 1.2072
# Epoch 10: val_accuracy did not improve from 0.58773
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.5357 - loss: 1.2176 - val_accuracy: 0.5724 - val_loss: 1.2312 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5486 - loss: 1.1999
# Epoch 11: val_accuracy did not improve from 0.58773
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 195ms/step - accuracy: 0.5668 - loss: 1.1795 - val_accuracy: 0.5503 - val_loss: 1.2735 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6015 - loss: 1.1294
# Epoch 12: val_accuracy did not improve from 0.58773
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.5953 - loss: 1.1392 - val_accuracy: 0.5724 - val_loss: 1.1985 - learning_rate: 1.0000e-05
# Score for fold 3: loss of 1.1985; compile_metrics of 57.24%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.3030 - loss: 9.9483
# Epoch 1: val_accuracy improved from None to 0.40034, saving model to baseline_cnn_fold_4.keras
#
# Epoch 1: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 22s 246ms/step - accuracy: 0.3230 - loss: 5.5860 - val_accuracy: 0.4003 - val_loss: 1.6721 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.3751 - loss: 1.7619
# Epoch 2: val_accuracy improved from 0.40034 to 0.45315, saving model to baseline_cnn_fold_4.keras
#
# Epoch 2: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.3791 - loss: 1.6580 - val_accuracy: 0.4532 - val_loss: 1.3594 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.3870 - loss: 1.4991
# Epoch 3: val_accuracy improved from 0.45315 to 0.49574, saving model to baseline_cnn_fold_4.keras
#
# Epoch 3: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.4021 - loss: 1.4556 - val_accuracy: 0.4957 - val_loss: 1.2748 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4419 - loss: 1.3792
# Epoch 4: val_accuracy improved from 0.49574 to 0.53833, saving model to baseline_cnn_fold_4.keras
#
# Epoch 4: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4362 - loss: 1.3838 - val_accuracy: 0.5383 - val_loss: 1.2518 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4461 - loss: 1.3646
# Epoch 5: val_accuracy improved from 0.53833 to 0.55707, saving model to baseline_cnn_fold_4.keras
#
# Epoch 5: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.4528 - loss: 1.3465 - val_accuracy: 0.5571 - val_loss: 1.1895 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4873 - loss: 1.3031
# Epoch 6: val_accuracy did not improve from 0.55707
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4851 - loss: 1.3155 - val_accuracy: 0.5571 - val_loss: 1.2037 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5097 - loss: 1.2829
# Epoch 7: val_accuracy improved from 0.55707 to 0.60647, saving model to baseline_cnn_fold_4.keras
#
# Epoch 7: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5140 - loss: 1.2751 - val_accuracy: 0.6065 - val_loss: 1.1352 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4998 - loss: 1.2624
# Epoch 8: val_accuracy did not improve from 0.60647
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5111 - loss: 1.2532 - val_accuracy: 0.5571 - val_loss: 1.1802 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5133 - loss: 1.2456
# Epoch 9: val_accuracy did not improve from 0.60647
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.5149 - loss: 1.2472 - val_accuracy: 0.5741 - val_loss: 1.1549 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5660 - loss: 1.1835
# Epoch 10: val_accuracy improved from 0.60647 to 0.61329, saving model to baseline_cnn_fold_4.keras
#
# Epoch 10: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.5489 - loss: 1.1980 - val_accuracy: 0.6133 - val_loss: 1.1148 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5669 - loss: 1.1888
# Epoch 11: val_accuracy did not improve from 0.61329
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.5591 - loss: 1.1980 - val_accuracy: 0.5945 - val_loss: 1.1201 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5631 - loss: 1.1987
# Epoch 12: val_accuracy improved from 0.61329 to 0.61670, saving model to baseline_cnn_fold_4.keras
#
# Epoch 12: finished saving model to baseline_cnn_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.5617 - loss: 1.1974 - val_accuracy: 0.6167 - val_loss: 1.0929 - learning_rate: 1.0000e-05
# Score for fold 4: loss of 1.0929; compile_metrics of 61.67%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.3154 - loss: 8.9310
# Epoch 1: val_accuracy improved from None to 0.44974, saving model to baseline_cnn_fold_5.keras
#
# Epoch 1: finished saving model to baseline_cnn_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 22s 232ms/step - accuracy: 0.3247 - loss: 4.7527 - val_accuracy: 0.4497 - val_loss: 1.3858 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.3711 - loss: 1.6030
# Epoch 2: val_accuracy improved from 0.44974 to 0.50596, saving model to baseline_cnn_fold_5.keras
#
# Epoch 2: finished saving model to baseline_cnn_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.3826 - loss: 1.5384 - val_accuracy: 0.5060 - val_loss: 1.2892 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4318 - loss: 1.4069
# Epoch 3: val_accuracy did not improve from 0.50596
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.4132 - loss: 1.4116 - val_accuracy: 0.4889 - val_loss: 1.3075 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.4321 - loss: 1.3684
# Epoch 4: val_accuracy did not improve from 0.50596
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.4451 - loss: 1.3595 - val_accuracy: 0.5060 - val_loss: 1.2913 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4822 - loss: 1.3250
# Epoch 5: val_accuracy improved from 0.50596 to 0.53663, saving model to baseline_cnn_fold_5.keras
#
# Epoch 5: finished saving model to baseline_cnn_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4877 - loss: 1.3104 - val_accuracy: 0.5366 - val_loss: 1.2224 - learning_rate: 1.0000e-05
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.4508 - loss: 1.3347
# Epoch 6: val_accuracy improved from 0.53663 to 0.53833, saving model to baseline_cnn_fold_5.keras
#
# Epoch 6: finished saving model to baseline_cnn_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.4685 - loss: 1.3128 - val_accuracy: 0.5383 - val_loss: 1.2149 - learning_rate: 1.0000e-05
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4824 - loss: 1.2876
# Epoch 7: val_accuracy improved from 0.53833 to 0.54174, saving model to baseline_cnn_fold_5.keras
#
# Epoch 7: finished saving model to baseline_cnn_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.4923 - loss: 1.2857 - val_accuracy: 0.5417 - val_loss: 1.2192 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.4933 - loss: 1.2764
# Epoch 8: val_accuracy improved from 0.54174 to 0.56388, saving model to baseline_cnn_fold_5.keras
#
# Epoch 8: finished saving model to baseline_cnn_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.5004 - loss: 1.2771 - val_accuracy: 0.5639 - val_loss: 1.1950 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.4917 - loss: 1.2802
# Epoch 9: val_accuracy did not improve from 0.56388
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.4974 - loss: 1.2802 - val_accuracy: 0.5383 - val_loss: 1.2248 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5193 - loss: 1.2871
# Epoch 10: val_accuracy did not improve from 0.56388
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.5094 - loss: 1.2795 - val_accuracy: 0.5434 - val_loss: 1.2085 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5076 - loss: 1.2585
# Epoch 11: val_accuracy did not improve from 0.56388
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.5047 - loss: 1.2706 - val_accuracy: 0.5571 - val_loss: 1.1957 - learning_rate: 1.0000e-06
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5029 - loss: 1.2690
# Epoch 12: val_accuracy did not improve from 0.56388
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.5034 - loss: 1.2630 - val_accuracy: 0.5588 - val_loss: 1.1930 - learning_rate: 1.0000e-06
# Score for fold 5: loss of 1.1930; compile_metrics of 55.88%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 1.2567 - Accuracy: 54.93%
# > Fold 2 - Loss: 1.0644 - Accuracy: 63.27%
# > Fold 3 - Loss: 1.1985 - Accuracy: 57.24%
# > Fold 4 - Loss: 1.0929 - Accuracy: 61.67%
# > Fold 5 - Loss: 1.1930 - Accuracy: 55.88%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 58.60% (+- 3.28%)
# > Loss: 1.1611
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
# model = tf.keras.models.load_model('efficientnetB0_fold_5.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.52      0.73      0.61        93
#         no_tumor       0.46      0.33      0.39        51
# meningioma_tumor       0.59      0.14      0.22        96
#  pituitary_tumor       0.57      0.91      0.70        87
#
#         accuracy                           0.54       327
#        macro avg       0.54      0.53      0.48       327
#     weighted avg       0.55      0.54      0.49       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(10).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
