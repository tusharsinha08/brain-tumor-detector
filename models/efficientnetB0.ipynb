# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:06<00:00, 132.51it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:02<00:00, 163.03it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:06<00:00, 127.01it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:06<00:00, 128.52it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:00<00:00, 163.21it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:00<00:00, 190.37it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:00<00:00, 186.22it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:00<00:00, 141.62it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: EfficientNetB0

# %%
from sklearn.model_selection import KFold
import tensorflow as tf

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    # Load the EfficientNetB0 model pretrained on ImageNet without the top layers
    efficientnetB0 = tf.keras.applications.EfficientNetB0(weights='imagenet',
                                                          include_top=False,
                                                          input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    # Build the custom model on top of the EfficientNetB0 base
    model = efficientnetB0.output
    model = tf.keras.layers.GlobalAveragePooling2D()(model)
    model = tf.keras.layers.Dense(1024,activation='relu')(model)
    model = tf.keras.layers.Dropout(rate=0.4)(model)
    model = tf.keras.layers.Dense(len(labels),activation='softmax')(model) # Use len(labels) for the output layer
    model = tf.keras.models.Model(inputs=efficientnetB0.input, outputs = model)

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"efficientnetB0_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr]
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.7092 - loss: 0.7613
# Epoch 1: val_accuracy improved from None to 0.85544, saving model to efficientnetB0_fold_1.keras
#
# Epoch 1: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 130s 875ms/step - accuracy: 0.7995 - loss: 0.5543 - val_accuracy: 0.8554 - val_loss: 0.8090 - learning_rate: 0.0010
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8708 - loss: 0.3770
# Epoch 2: val_accuracy did not improve from 0.85544
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8748 - loss: 0.3608 - val_accuracy: 0.8554 - val_loss: 0.4778 - learning_rate: 0.0010
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9019 - loss: 0.2759
# Epoch 3: val_accuracy improved from 0.85544 to 0.86054, saving model to efficientnetB0_fold_1.keras
#
# Epoch 3: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.8987 - loss: 0.2933 - val_accuracy: 0.8605 - val_loss: 0.3963 - learning_rate: 0.0010
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9157 - loss: 0.2273
# Epoch 4: val_accuracy did not improve from 0.86054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.9144 - loss: 0.2399 - val_accuracy: 0.8452 - val_loss: 0.7366 - learning_rate: 0.0010
# Epoch 5/12
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9415 - loss: 0.1673
# Epoch 5: val_accuracy improved from 0.86054 to 0.89456, saving model to efficientnetB0_fold_1.keras
#
# Epoch 5: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.9370 - loss: 0.1729 - val_accuracy: 0.8946 - val_loss: 0.3749 - learning_rate: 0.0010
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9465 - loss: 0.1693
# Epoch 6: val_accuracy did not improve from 0.89456
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9395 - loss: 0.1863 - val_accuracy: 0.8741 - val_loss: 0.6079 - learning_rate: 0.0010
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9392 - loss: 0.1924
# Epoch 7: val_accuracy did not improve from 0.89456
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9442 - loss: 0.1602 - val_accuracy: 0.7636 - val_loss: 1.4503 - learning_rate: 0.0010
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9644 - loss: 0.0878
# Epoch 8: val_accuracy improved from 0.89456 to 0.91667, saving model to efficientnetB0_fold_1.keras
#
# Epoch 8: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9655 - loss: 0.0944 - val_accuracy: 0.9167 - val_loss: 0.3272 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9752 - loss: 0.0749
# Epoch 9: val_accuracy improved from 0.91667 to 0.92687, saving model to efficientnetB0_fold_1.keras
#
# Epoch 9: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.9770 - loss: 0.0639 - val_accuracy: 0.9269 - val_loss: 0.2937 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9744 - loss: 0.0618
# Epoch 10: val_accuracy did not improve from 0.92687
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.9808 - loss: 0.0562 - val_accuracy: 0.9269 - val_loss: 0.2757 - learning_rate: 1.0000e-04
# Epoch 11/12
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9842 - loss: 0.0557
# Epoch 11: val_accuracy improved from 0.92687 to 0.93367, saving model to efficientnetB0_fold_1.keras
#
# Epoch 11: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.9851 - loss: 0.0478 - val_accuracy: 0.9337 - val_loss: 0.2460 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9813 - loss: 0.0463
# Epoch 12: val_accuracy improved from 0.93367 to 0.94218, saving model to efficientnetB0_fold_1.keras
#
# Epoch 12: finished saving model to efficientnetB0_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9830 - loss: 0.0476 - val_accuracy: 0.9422 - val_loss: 0.2226 - learning_rate: 1.0000e-04
# Score for fold 1: loss of 0.2226; compile_metrics of 94.22%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.6787 - loss: 0.7589
# Epoch 1: val_accuracy improved from None to 0.83333, saving model to efficientnetB0_fold_2.keras
#
# Epoch 1: finished saving model to efficientnetB0_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 127s 819ms/step - accuracy: 0.7871 - loss: 0.5665 - val_accuracy: 0.8333 - val_loss: 0.7323 - learning_rate: 0.0010
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8729 - loss: 0.3636
# Epoch 2: val_accuracy improved from 0.83333 to 0.88776, saving model to efficientnetB0_fold_2.keras
#
# Epoch 2: finished saving model to efficientnetB0_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.8821 - loss: 0.3541 - val_accuracy: 0.8878 - val_loss: 0.3419 - learning_rate: 0.0010
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9163 - loss: 0.2748
# Epoch 3: val_accuracy did not improve from 0.88776
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9204 - loss: 0.2491 - val_accuracy: 0.8095 - val_loss: 0.7975 - learning_rate: 0.0010
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9188 - loss: 0.2278
# Epoch 4: val_accuracy did not improve from 0.88776
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.9217 - loss: 0.2325 - val_accuracy: 0.5357 - val_loss: 2.5336 - learning_rate: 0.0010
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9223 - loss: 0.2173
# Epoch 5: val_accuracy did not improve from 0.88776
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.9421 - loss: 0.1639 - val_accuracy: 0.7993 - val_loss: 0.8580 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9532 - loss: 0.1258
# Epoch 6: val_accuracy improved from 0.88776 to 0.89626, saving model to efficientnetB0_fold_2.keras
#
# Epoch 6: finished saving model to efficientnetB0_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.9617 - loss: 0.1075 - val_accuracy: 0.8963 - val_loss: 0.4366 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9745 - loss: 0.0858
# Epoch 7: val_accuracy improved from 0.89626 to 0.91667, saving model to efficientnetB0_fold_2.keras
#
# Epoch 7: finished saving model to efficientnetB0_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.9745 - loss: 0.0880 - val_accuracy: 0.9167 - val_loss: 0.3285 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9771 - loss: 0.0708
# Epoch 8: val_accuracy improved from 0.91667 to 0.92517, saving model to efficientnetB0_fold_2.keras
#
# Epoch 8: finished saving model to efficientnetB0_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9766 - loss: 0.0711 - val_accuracy: 0.9252 - val_loss: 0.3222 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9710 - loss: 0.0817
# Epoch 9: val_accuracy did not improve from 0.92517
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9740 - loss: 0.0741 - val_accuracy: 0.9184 - val_loss: 0.3753 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9739 - loss: 0.0613
# Epoch 10: val_accuracy did not improve from 0.92517
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9736 - loss: 0.0690 - val_accuracy: 0.9099 - val_loss: 0.3954 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9832 - loss: 0.0455
# Epoch 11: val_accuracy did not improve from 0.92517
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9830 - loss: 0.0488 - val_accuracy: 0.9133 - val_loss: 0.4072 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9751 - loss: 0.0728
# Epoch 12: val_accuracy did not improve from 0.92517
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9762 - loss: 0.0679 - val_accuracy: 0.9150 - val_loss: 0.3778 - learning_rate: 1.0000e-05
# Score for fold 2: loss of 0.3778; compile_metrics of 91.50%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.6899 - loss: 0.7818
# Epoch 1: val_accuracy improved from None to 0.86201, saving model to efficientnetB0_fold_3.keras
#
# Epoch 1: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 125s 793ms/step - accuracy: 0.7791 - loss: 0.5892 - val_accuracy: 0.8620 - val_loss: 0.3968 - learning_rate: 0.0010
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8908 - loss: 0.3188
# Epoch 2: val_accuracy did not improve from 0.86201
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8834 - loss: 0.3463 - val_accuracy: 0.8501 - val_loss: 0.6120 - learning_rate: 0.0010
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9146 - loss: 0.2504
# Epoch 3: val_accuracy did not improve from 0.86201
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.9145 - loss: 0.2504 - val_accuracy: 0.8075 - val_loss: 0.6964 - learning_rate: 0.0010
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9270 - loss: 0.2403
# Epoch 4: val_accuracy improved from 0.86201 to 0.87905, saving model to efficientnetB0_fold_3.keras
#
# Epoch 4: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9383 - loss: 0.1965 - val_accuracy: 0.8790 - val_loss: 0.4281 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9592 - loss: 0.1245
# Epoch 5: val_accuracy improved from 0.87905 to 0.88927, saving model to efficientnetB0_fold_3.keras
#
# Epoch 5: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9596 - loss: 0.1161 - val_accuracy: 0.8893 - val_loss: 0.3918 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9646 - loss: 0.1051
# Epoch 6: val_accuracy improved from 0.88927 to 0.89949, saving model to efficientnetB0_fold_3.keras
#
# Epoch 6: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9617 - loss: 0.1132 - val_accuracy: 0.8995 - val_loss: 0.3381 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9707 - loss: 0.0889
# Epoch 7: val_accuracy did not improve from 0.89949
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.9681 - loss: 0.0920 - val_accuracy: 0.8944 - val_loss: 0.3527 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9698 - loss: 0.0922
# Epoch 8: val_accuracy improved from 0.89949 to 0.90460, saving model to efficientnetB0_fold_3.keras
#
# Epoch 8: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9711 - loss: 0.0872 - val_accuracy: 0.9046 - val_loss: 0.3396 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9671 - loss: 0.0854
# Epoch 9: val_accuracy improved from 0.90460 to 0.90971, saving model to efficientnetB0_fold_3.keras
#
# Epoch 9: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9672 - loss: 0.0847 - val_accuracy: 0.9097 - val_loss: 0.3603 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9774 - loss: 0.0787
# Epoch 10: val_accuracy improved from 0.90971 to 0.91312, saving model to efficientnetB0_fold_3.keras
#
# Epoch 10: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.9791 - loss: 0.0696 - val_accuracy: 0.9131 - val_loss: 0.3474 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9730 - loss: 0.0639
# Epoch 11: val_accuracy did not improve from 0.91312
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9719 - loss: 0.0711 - val_accuracy: 0.9114 - val_loss: 0.3675 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9848 - loss: 0.0459
# Epoch 12: val_accuracy improved from 0.91312 to 0.91823, saving model to efficientnetB0_fold_3.keras
#
# Epoch 12: finished saving model to efficientnetB0_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.9804 - loss: 0.0538 - val_accuracy: 0.9182 - val_loss: 0.3341 - learning_rate: 1.0000e-04
# Score for fold 3: loss of 0.3341; compile_metrics of 91.82%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - accuracy: 0.6876 - loss: 0.7571
# Epoch 1: val_accuracy improved from None to 0.85179, saving model to efficientnetB0_fold_4.keras
#
# Epoch 1: finished saving model to efficientnetB0_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 126s 813ms/step - accuracy: 0.7881 - loss: 0.5539 - val_accuracy: 0.8518 - val_loss: 0.5138 - learning_rate: 0.0010
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8754 - loss: 0.3497
# Epoch 2: val_accuracy improved from 0.85179 to 0.87223, saving model to efficientnetB0_fold_4.keras
#
# Epoch 2: finished saving model to efficientnetB0_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8843 - loss: 0.3486 - val_accuracy: 0.8722 - val_loss: 0.5688 - learning_rate: 0.0010
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9242 - loss: 0.2332
# Epoch 3: val_accuracy did not improve from 0.87223
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9179 - loss: 0.2303 - val_accuracy: 0.8688 - val_loss: 0.4347 - learning_rate: 0.0010
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9228 - loss: 0.1939
# Epoch 4: val_accuracy did not improve from 0.87223
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9281 - loss: 0.1969 - val_accuracy: 0.7462 - val_loss: 0.9103 - learning_rate: 0.0010
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9369 - loss: 0.1961
# Epoch 5: val_accuracy did not improve from 0.87223
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.9464 - loss: 0.1535 - val_accuracy: 0.8313 - val_loss: 0.6421 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9644 - loss: 0.1038
# Epoch 6: val_accuracy did not improve from 0.87223
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9638 - loss: 0.1057 - val_accuracy: 0.8620 - val_loss: 0.5320 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9675 - loss: 0.0878
# Epoch 7: val_accuracy improved from 0.87223 to 0.91482, saving model to efficientnetB0_fold_4.keras
#
# Epoch 7: finished saving model to efficientnetB0_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.9643 - loss: 0.0916 - val_accuracy: 0.9148 - val_loss: 0.3022 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9741 - loss: 0.0729
# Epoch 8: val_accuracy improved from 0.91482 to 0.92675, saving model to efficientnetB0_fold_4.keras
#
# Epoch 8: finished saving model to efficientnetB0_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9711 - loss: 0.0788 - val_accuracy: 0.9267 - val_loss: 0.2711 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9775 - loss: 0.0753
# Epoch 9: val_accuracy improved from 0.92675 to 0.92845, saving model to efficientnetB0_fold_4.keras
#
# Epoch 9: finished saving model to efficientnetB0_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9732 - loss: 0.0806 - val_accuracy: 0.9284 - val_loss: 0.2619 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9689 - loss: 0.0933
# Epoch 10: val_accuracy did not improve from 0.92845
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.9706 - loss: 0.0861 - val_accuracy: 0.9267 - val_loss: 0.2522 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9689 - loss: 0.0737
# Epoch 11: val_accuracy did not improve from 0.92845
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9672 - loss: 0.0775 - val_accuracy: 0.9250 - val_loss: 0.2557 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9739 - loss: 0.0778
# Epoch 12: val_accuracy did not improve from 0.92845
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.9728 - loss: 0.0887 - val_accuracy: 0.9284 - val_loss: 0.2530 - learning_rate: 1.0000e-06
# Score for fold 4: loss of 0.2530; compile_metrics of 92.84%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - accuracy: 0.6912 - loss: 0.7734
# Epoch 1: val_accuracy improved from None to 0.72061, saving model to efficientnetB0_fold_5.keras
#
# Epoch 1: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 131s 805ms/step - accuracy: 0.7774 - loss: 0.5979 - val_accuracy: 0.7206 - val_loss: 1.4828 - learning_rate: 0.0010
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8627 - loss: 0.3890
# Epoch 2: val_accuracy improved from 0.72061 to 0.88416, saving model to efficientnetB0_fold_5.keras
#
# Epoch 2: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8698 - loss: 0.3729 - val_accuracy: 0.8842 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9078 - loss: 0.2871
# Epoch 3: val_accuracy did not improve from 0.88416
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.9132 - loss: 0.2576 - val_accuracy: 0.8620 - val_loss: 0.6482 - learning_rate: 0.0010
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9335 - loss: 0.1857
# Epoch 4: val_accuracy did not improve from 0.88416
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9255 - loss: 0.2084 - val_accuracy: 0.8688 - val_loss: 0.3651 - learning_rate: 0.0010
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9393 - loss: 0.1709
# Epoch 5: val_accuracy improved from 0.88416 to 0.89267, saving model to efficientnetB0_fold_5.keras
#
# Epoch 5: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.9489 - loss: 0.1487 - val_accuracy: 0.8927 - val_loss: 0.3249 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9634 - loss: 0.1161
# Epoch 6: val_accuracy improved from 0.89267 to 0.90119, saving model to efficientnetB0_fold_5.keras
#
# Epoch 6: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9634 - loss: 0.1152 - val_accuracy: 0.9012 - val_loss: 0.3050 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9685 - loss: 0.0797
# Epoch 7: val_accuracy improved from 0.90119 to 0.90460, saving model to efficientnetB0_fold_5.keras
#
# Epoch 7: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.9664 - loss: 0.0882 - val_accuracy: 0.9046 - val_loss: 0.2779 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9727 - loss: 0.0700
# Epoch 8: val_accuracy did not improve from 0.90460
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.9706 - loss: 0.0766 - val_accuracy: 0.9029 - val_loss: 0.3092 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9708 - loss: 0.0769
# Epoch 9: val_accuracy improved from 0.90460 to 0.91823, saving model to efficientnetB0_fold_5.keras
#
# Epoch 9: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.9757 - loss: 0.0616 - val_accuracy: 0.9182 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9803 - loss: 0.0657
# Epoch 10: val_accuracy did not improve from 0.91823
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.9791 - loss: 0.0644 - val_accuracy: 0.9165 - val_loss: 0.2411 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9855 - loss: 0.0467
# Epoch 11: val_accuracy improved from 0.91823 to 0.92164, saving model to efficientnetB0_fold_5.keras
#
# Epoch 11: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.9813 - loss: 0.0544 - val_accuracy: 0.9216 - val_loss: 0.2324 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9839 - loss: 0.0509
# Epoch 12: val_accuracy improved from 0.92164 to 0.93186, saving model to efficientnetB0_fold_5.keras
#
# Epoch 12: finished saving model to efficientnetB0_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9830 - loss: 0.0515 - val_accuracy: 0.9319 - val_loss: 0.2169 - learning_rate: 1.0000e-04
# Score for fold 5: loss of 0.2169; compile_metrics of 93.19%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.2226 - Accuracy: 94.22%
# > Fold 2 - Loss: 0.3778 - Accuracy: 91.50%
# > Fold 3 - Loss: 0.3341 - Accuracy: 91.82%
# > Fold 4 - Loss: 0.2530 - Accuracy: 92.84%
# > Fold 5 - Loss: 0.2169 - Accuracy: 93.19%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 92.71% (+- 0.98%)
# > Loss: 0.2809
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
# model = tf.keras.models.load_model('efficientnetB0_fold_5.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 667ms/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.96      0.95      0.95        93
#         no_tumor       1.00      0.92      0.96        51
# meningioma_tumor       0.98      0.85      0.91        96
#  pituitary_tumor       0.84      1.00      0.91        87
#
#         accuracy                           0.93       327
#        macro avg       0.94      0.93      0.93       327
#     weighted avg       0.94      0.93      0.93       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
