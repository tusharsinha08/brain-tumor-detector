# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:07<00:00, 107.41it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:02<00:00, 158.84it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:06<00:00, 132.58it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:07<00:00, 111.83it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:00<00:00, 171.05it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:00<00:00, 190.32it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:00<00:00, 196.96it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:00<00:00, 144.86it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: Hybrid (ResNet50 + EfficientNetB0)

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    # Shared input layer
    input_layer = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    # Base Model 1: ResNet50
    resnet50_base = tf.keras.applications.ResNet50(weights='imagenet', include_top=False)
    resnet50_base.trainable = False # Freeze to avoid OOM errors
    resnet_out = resnet50_base(input_layer)
    resnet_pool = layers.GlobalAveragePooling2D()(resnet_out)

    # Base Model 2: EfficientNetB0
    efficientnet_base = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False)
    efficientnet_base.trainable = False # Freeze to avoid OOM errors
    effnet_out = efficientnet_base(input_layer)
    effnet_pool = layers.GlobalAveragePooling2D()(effnet_out)

    # Concatenate features from both models
    merged = layers.Concatenate()([resnet_pool, effnet_pool])

    # Custom classification head
    x = layers.Dense(1024, activation='relu')(merged)
    x = layers.Dropout(0.4)(x)

    # Output layer
    output_layer = layers.Dense(len(labels), activation='softmax')(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"hybrid_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr],
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.5117 - loss: 1.1829
# Epoch 1: val_accuracy improved from None to 0.79592, saving model to hybrid_fold_1.keras
#
# Epoch 1: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 89s 776ms/step - accuracy: 0.6232 - loss: 0.9178 - val_accuracy: 0.7959 - val_loss: 0.5376 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7685 - loss: 0.6083
# Epoch 2: val_accuracy improved from 0.79592 to 0.80102, saving model to hybrid_fold_1.keras
#
# Epoch 2: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.7782 - loss: 0.5721 - val_accuracy: 0.8010 - val_loss: 0.5572 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8120 - loss: 0.5057
# Epoch 3: val_accuracy did not improve from 0.80102
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.8161 - loss: 0.4824 - val_accuracy: 0.7976 - val_loss: 0.5479 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8357 - loss: 0.4410
# Epoch 4: val_accuracy improved from 0.80102 to 0.83673, saving model to hybrid_fold_1.keras
#
# Epoch 4: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.8348 - loss: 0.4420 - val_accuracy: 0.8367 - val_loss: 0.4771 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8460 - loss: 0.3929
# Epoch 5: val_accuracy did not improve from 0.83673
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8467 - loss: 0.4063 - val_accuracy: 0.8333 - val_loss: 0.4558 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8502 - loss: 0.4016
# Epoch 6: val_accuracy improved from 0.83673 to 0.85714, saving model to hybrid_fold_1.keras
#
# Epoch 6: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 215ms/step - accuracy: 0.8548 - loss: 0.3846 - val_accuracy: 0.8571 - val_loss: 0.4085 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8830 - loss: 0.3286
# Epoch 7: val_accuracy improved from 0.85714 to 0.86735, saving model to hybrid_fold_1.keras
#
# Epoch 7: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.8765 - loss: 0.3338 - val_accuracy: 0.8673 - val_loss: 0.4055 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8840 - loss: 0.3034
# Epoch 8: val_accuracy did not improve from 0.86735
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.8770 - loss: 0.3257 - val_accuracy: 0.8673 - val_loss: 0.3533 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8820 - loss: 0.3166
# Epoch 9: val_accuracy did not improve from 0.86735
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.8863 - loss: 0.3101 - val_accuracy: 0.8537 - val_loss: 0.4050 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8905 - loss: 0.3115
# Epoch 10: val_accuracy improved from 0.86735 to 0.87755, saving model to hybrid_fold_1.keras
#
# Epoch 10: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.9000 - loss: 0.2819 - val_accuracy: 0.8776 - val_loss: 0.3587 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9081 - loss: 0.2594
# Epoch 11: val_accuracy did not improve from 0.87755
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9089 - loss: 0.2642 - val_accuracy: 0.8776 - val_loss: 0.3617 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9147 - loss: 0.2544
# Epoch 12: val_accuracy did not improve from 0.87755
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.9068 - loss: 0.2662 - val_accuracy: 0.8588 - val_loss: 0.3779 - learning_rate: 1.0000e-05
# Score for fold 1: loss of 0.3779; compile_metrics of 85.88%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5114 - loss: 1.2478
# Epoch 1: val_accuracy improved from None to 0.80612, saving model to hybrid_fold_2.keras
#
# Epoch 1: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 74s 627ms/step - accuracy: 0.6194 - loss: 0.9528 - val_accuracy: 0.8061 - val_loss: 0.5293 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.7445 - loss: 0.6495
# Epoch 2: val_accuracy did not improve from 0.80612
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.7735 - loss: 0.5894 - val_accuracy: 0.7993 - val_loss: 0.5475 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8215 - loss: 0.4799
# Epoch 3: val_accuracy improved from 0.80612 to 0.82823, saving model to hybrid_fold_2.keras
#
# Epoch 3: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8114 - loss: 0.4835 - val_accuracy: 0.8282 - val_loss: 0.4497 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8098 - loss: 0.4602
# Epoch 4: val_accuracy did not improve from 0.82823
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8331 - loss: 0.4287 - val_accuracy: 0.8027 - val_loss: 0.5338 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8563 - loss: 0.3972
# Epoch 5: val_accuracy improved from 0.82823 to 0.83673, saving model to hybrid_fold_2.keras
#
# Epoch 5: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8561 - loss: 0.3788 - val_accuracy: 0.8367 - val_loss: 0.4939 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8645 - loss: 0.3575
# Epoch 6: val_accuracy did not improve from 0.83673
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8612 - loss: 0.3596 - val_accuracy: 0.8248 - val_loss: 0.5090 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8564 - loss: 0.3581
# Epoch 7: val_accuracy improved from 0.83673 to 0.86054, saving model to hybrid_fold_2.keras
#
# Epoch 7: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.8685 - loss: 0.3421 - val_accuracy: 0.8605 - val_loss: 0.3813 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9050 - loss: 0.2717
# Epoch 8: val_accuracy did not improve from 0.86054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8885 - loss: 0.3040 - val_accuracy: 0.8435 - val_loss: 0.4292 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8880 - loss: 0.2950
# Epoch 9: val_accuracy did not improve from 0.86054
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.8906 - loss: 0.2961 - val_accuracy: 0.8231 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9142 - loss: 0.2523
# Epoch 10: val_accuracy did not improve from 0.86054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.9008 - loss: 0.2690 - val_accuracy: 0.8486 - val_loss: 0.4092 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9025 - loss: 0.2537
# Epoch 11: val_accuracy did not improve from 0.86054
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9059 - loss: 0.2562 - val_accuracy: 0.8554 - val_loss: 0.4002 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9109 - loss: 0.2476
# Epoch 12: val_accuracy did not improve from 0.86054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9140 - loss: 0.2459 - val_accuracy: 0.8554 - val_loss: 0.3978 - learning_rate: 1.0000e-06
# Score for fold 2: loss of 0.3978; compile_metrics of 85.54%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.5043 - loss: 1.2337
# Epoch 1: val_accuracy improved from None to 0.75128, saving model to hybrid_fold_3.keras
#
# Epoch 1: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 86s 798ms/step - accuracy: 0.6209 - loss: 0.9407 - val_accuracy: 0.7513 - val_loss: 0.6418 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7710 - loss: 0.5752
# Epoch 2: val_accuracy improved from 0.75128 to 0.76320, saving model to hybrid_fold_3.keras
#
# Epoch 2: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.7732 - loss: 0.5755 - val_accuracy: 0.7632 - val_loss: 0.6406 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8237 - loss: 0.4725
# Epoch 3: val_accuracy improved from 0.76320 to 0.80920, saving model to hybrid_fold_3.keras
#
# Epoch 3: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8128 - loss: 0.4935 - val_accuracy: 0.8092 - val_loss: 0.4866 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8449 - loss: 0.4158
# Epoch 4: val_accuracy did not improve from 0.80920
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.8404 - loss: 0.4195 - val_accuracy: 0.7802 - val_loss: 0.5386 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8483 - loss: 0.4004
# Epoch 5: val_accuracy improved from 0.80920 to 0.84327, saving model to hybrid_fold_3.keras
#
# Epoch 5: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8455 - loss: 0.4088 - val_accuracy: 0.8433 - val_loss: 0.4254 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8524 - loss: 0.3750
# Epoch 6: val_accuracy did not improve from 0.84327
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.8638 - loss: 0.3772 - val_accuracy: 0.8160 - val_loss: 0.5030 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8628 - loss: 0.3486
# Epoch 7: val_accuracy did not improve from 0.84327
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.8664 - loss: 0.3432 - val_accuracy: 0.8177 - val_loss: 0.4427 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8817 - loss: 0.3103
# Epoch 8: val_accuracy did not improve from 0.84327
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.8860 - loss: 0.3053 - val_accuracy: 0.8399 - val_loss: 0.4297 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8816 - loss: 0.3144
# Epoch 9: val_accuracy did not improve from 0.84327
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.8894 - loss: 0.2944 - val_accuracy: 0.8245 - val_loss: 0.4581 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8994 - loss: 0.2779
# Epoch 10: val_accuracy did not improve from 0.84327
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9026 - loss: 0.2788 - val_accuracy: 0.8348 - val_loss: 0.4401 - learning_rate: 1.0000e-06
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9007 - loss: 0.2726
# Epoch 11: val_accuracy did not improve from 0.84327
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.8987 - loss: 0.2782 - val_accuracy: 0.8382 - val_loss: 0.4316 - learning_rate: 1.0000e-06
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9113 - loss: 0.2716
# Epoch 12: val_accuracy did not improve from 0.84327
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.9017 - loss: 0.2830 - val_accuracy: 0.8382 - val_loss: 0.4312 - learning_rate: 1.0000e-07
# Score for fold 3: loss of 0.4312; compile_metrics of 83.82%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4877 - loss: 1.3468
# Epoch 1: val_accuracy improved from None to 0.73254, saving model to hybrid_fold_4.keras
#
# Epoch 1: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 73s 608ms/step - accuracy: 0.6123 - loss: 0.9884 - val_accuracy: 0.7325 - val_loss: 0.6918 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7637 - loss: 0.5900
# Epoch 2: val_accuracy improved from 0.73254 to 0.79557, saving model to hybrid_fold_4.keras
#
# Epoch 2: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 220ms/step - accuracy: 0.7660 - loss: 0.5980 - val_accuracy: 0.7956 - val_loss: 0.5376 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8185 - loss: 0.4997
# Epoch 3: val_accuracy did not improve from 0.79557
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8115 - loss: 0.4885 - val_accuracy: 0.7905 - val_loss: 0.5488 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8287 - loss: 0.4431
# Epoch 4: val_accuracy improved from 0.79557 to 0.81261, saving model to hybrid_fold_4.keras
#
# Epoch 4: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.8383 - loss: 0.4387 - val_accuracy: 0.8126 - val_loss: 0.5163 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8496 - loss: 0.3985
# Epoch 5: val_accuracy improved from 0.81261 to 0.83135, saving model to hybrid_fold_4.keras
#
# Epoch 5: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.8455 - loss: 0.4016 - val_accuracy: 0.8313 - val_loss: 0.4799 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8575 - loss: 0.3735
# Epoch 6: val_accuracy improved from 0.83135 to 0.86201, saving model to hybrid_fold_4.keras
#
# Epoch 6: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 215ms/step - accuracy: 0.8626 - loss: 0.3660 - val_accuracy: 0.8620 - val_loss: 0.4296 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8764 - loss: 0.3302
# Epoch 7: val_accuracy did not improve from 0.86201
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.8694 - loss: 0.3479 - val_accuracy: 0.8518 - val_loss: 0.4768 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8857 - loss: 0.3297
# Epoch 8: val_accuracy improved from 0.86201 to 0.87394, saving model to hybrid_fold_4.keras
#
# Epoch 8: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 217ms/step - accuracy: 0.8779 - loss: 0.3341 - val_accuracy: 0.8739 - val_loss: 0.3979 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8911 - loss: 0.3086
# Epoch 9: val_accuracy did not improve from 0.87394
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8894 - loss: 0.3120 - val_accuracy: 0.8603 - val_loss: 0.4191 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8901 - loss: 0.3007
# Epoch 10: val_accuracy did not improve from 0.87394
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.8851 - loss: 0.3009 - val_accuracy: 0.8620 - val_loss: 0.4307 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8980 - loss: 0.2616
# Epoch 11: val_accuracy did not improve from 0.87394
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.9047 - loss: 0.2563 - val_accuracy: 0.8705 - val_loss: 0.4267 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9179 - loss: 0.2301
# Epoch 12: val_accuracy did not improve from 0.87394
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9102 - loss: 0.2450 - val_accuracy: 0.8722 - val_loss: 0.4052 - learning_rate: 1.0000e-05
# Score for fold 4: loss of 0.4052; compile_metrics of 87.22%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5050 - loss: 1.1841
# Epoch 1: val_accuracy improved from None to 0.73935, saving model to hybrid_fold_5.keras
#
# Epoch 1: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 74s 614ms/step - accuracy: 0.6247 - loss: 0.9151 - val_accuracy: 0.7394 - val_loss: 0.6228 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7744 - loss: 0.5923
# Epoch 2: val_accuracy improved from 0.73935 to 0.82794, saving model to hybrid_fold_5.keras
#
# Epoch 2: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.7826 - loss: 0.5802 - val_accuracy: 0.8279 - val_loss: 0.4527 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8138 - loss: 0.4893
# Epoch 3: val_accuracy did not improve from 0.82794
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.8145 - loss: 0.4866 - val_accuracy: 0.7785 - val_loss: 0.5352 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8512 - loss: 0.3822
# Epoch 4: val_accuracy improved from 0.82794 to 0.85860, saving model to hybrid_fold_5.keras
#
# Epoch 4: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.8374 - loss: 0.4200 - val_accuracy: 0.8586 - val_loss: 0.3829 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8482 - loss: 0.4176
# Epoch 5: val_accuracy did not improve from 0.85860
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 196ms/step - accuracy: 0.8528 - loss: 0.4013 - val_accuracy: 0.8075 - val_loss: 0.4972 - learning_rate: 1.0000e-04
# Epoch 6/12
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8711 - loss: 0.3616
# Epoch 6: val_accuracy did not improve from 0.85860
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8634 - loss: 0.3696 - val_accuracy: 0.8365 - val_loss: 0.4125 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8730 - loss: 0.3322
# Epoch 7: val_accuracy did not improve from 0.85860
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.8774 - loss: 0.3323 - val_accuracy: 0.8450 - val_loss: 0.3936 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8661 - loss: 0.3539
# Epoch 8: val_accuracy did not improve from 0.85860
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8834 - loss: 0.3190 - val_accuracy: 0.8365 - val_loss: 0.3997 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8875 - loss: 0.3068
# Epoch 9: val_accuracy did not improve from 0.85860
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.8860 - loss: 0.3043 - val_accuracy: 0.8484 - val_loss: 0.3918 - learning_rate: 1.0000e-06
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9030 - loss: 0.2909
# Epoch 10: val_accuracy did not improve from 0.85860
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.8911 - loss: 0.3017 - val_accuracy: 0.8501 - val_loss: 0.3825 - learning_rate: 1.0000e-06
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8884 - loss: 0.2949
# Epoch 11: val_accuracy did not improve from 0.85860
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.8851 - loss: 0.3112 - val_accuracy: 0.8501 - val_loss: 0.3819 - learning_rate: 1.0000e-07
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8917 - loss: 0.3102
# Epoch 12: val_accuracy did not improve from 0.85860
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 196ms/step - accuracy: 0.8915 - loss: 0.3017 - val_accuracy: 0.8518 - val_loss: 0.3814 - learning_rate: 1.0000e-07
# Score for fold 5: loss of 0.3814; compile_metrics of 85.18%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.3779 - Accuracy: 85.88%
# > Fold 2 - Loss: 0.3978 - Accuracy: 85.54%
# > Fold 3 - Loss: 0.4312 - Accuracy: 83.82%
# > Fold 4 - Loss: 0.4052 - Accuracy: 87.22%
# > Fold 5 - Loss: 0.3814 - Accuracy: 85.18%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 85.53% (+- 1.10%)
# > Loss: 0.3987
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
# model = tf.keras.models.load_model('efficientnetB0_fold_5.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.87      0.89      0.88        93
#         no_tumor       0.98      0.88      0.93        51
# meningioma_tumor       0.84      0.72      0.78        96
#  pituitary_tumor       0.81      0.97      0.88        87
#
#         accuracy                           0.86       327
#        macro avg       0.88      0.86      0.87       327
#     weighted avg       0.86      0.86      0.86       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(10).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
