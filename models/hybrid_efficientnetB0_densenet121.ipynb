# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:18<00:00, 45.10it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:07<00:00, 51.75it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:17<00:00, 45.84it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:26<00:00, 31.37it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:04<00:00, 23.78it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:03<00:00, 29.61it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:07<00:00, 15.25it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [01:06<00:00,  1.11it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: Hybrid (DenseNet121 + EfficientNetB0)

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    # Shared input layer
    input_layer = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    # Base Model 1: DenseNet121
    densenet_base = tf.keras.applications.DenseNet121(weights='imagenet', include_top=False)
    # Fine-tune: Unfreeze the last block
    densenet_base.trainable = True
    for layer in densenet_base.layers[:-20]: # Keep most layers frozen
        layer.trainable = False
    densenet_out = densenet_base(input_layer)
    densenet_pool = layers.GlobalAveragePooling2D()(densenet_out)

    # Base Model 2: EfficientNetB0
    efficientnet_base = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False)
    # Fine-tune: Unfreeze the top layers
    efficientnet_base.trainable = True
    for layer in efficientnet_base.layers[:-20]: # Keep most layers frozen
        layer.trainable = False
    effnet_out = efficientnet_base(input_layer)
    effnet_pool = layers.GlobalAveragePooling2D()(effnet_out)

    # Concatenate features from both models
    merged = layers.Concatenate()([densenet_pool, effnet_pool])

    # Custom classification head
    x = layers.Dense(512, activation='relu')(merged)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    # Output layer
    output_layer = layers.Dense(len(labels), activation='softmax')(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    # Compile with a low learning rate for fine-tuning
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"hybrid_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr],
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.3991 - loss: 1.3887
# Epoch 1: val_accuracy improved from None to 0.70918, saving model to hybrid_fold_1.keras
#
# Epoch 1: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 126s 993ms/step - accuracy: 0.4960 - loss: 1.2178 - val_accuracy: 0.7092 - val_loss: 0.9078 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6523 - loss: 0.9763
# Epoch 2: val_accuracy improved from 0.70918 to 0.72449, saving model to hybrid_fold_1.keras
#
# Epoch 2: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.6726 - loss: 0.9413 - val_accuracy: 0.7245 - val_loss: 0.8246 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7518 - loss: 0.8095
# Epoch 3: val_accuracy improved from 0.72449 to 0.75850, saving model to hybrid_fold_1.keras
#
# Epoch 3: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.7569 - loss: 0.8066 - val_accuracy: 0.7585 - val_loss: 0.7955 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7860 - loss: 0.7640
# Epoch 4: val_accuracy did not improve from 0.75850
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.7871 - loss: 0.7613 - val_accuracy: 0.7517 - val_loss: 0.8534 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8235 - loss: 0.7105
# Epoch 5: val_accuracy improved from 0.75850 to 0.81122, saving model to hybrid_fold_1.keras
#
# Epoch 5: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.8208 - loss: 0.7157 - val_accuracy: 0.8112 - val_loss: 0.7411 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8412 - loss: 0.6899
# Epoch 6: val_accuracy improved from 0.81122 to 0.81633, saving model to hybrid_fold_1.keras
#
# Epoch 6: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - accuracy: 0.8472 - loss: 0.6778 - val_accuracy: 0.8163 - val_loss: 0.7350 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8580 - loss: 0.6612
# Epoch 7: val_accuracy improved from 0.81633 to 0.82993, saving model to hybrid_fold_1.keras
#
# Epoch 7: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8565 - loss: 0.6615 - val_accuracy: 0.8299 - val_loss: 0.7172 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8675 - loss: 0.6420
# Epoch 8: val_accuracy did not improve from 0.82993
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8778 - loss: 0.6286 - val_accuracy: 0.8282 - val_loss: 0.7351 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8805 - loss: 0.6194
# Epoch 9: val_accuracy did not improve from 0.82993
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.8846 - loss: 0.6099 - val_accuracy: 0.8265 - val_loss: 0.7673 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8854 - loss: 0.6076
# Epoch 10: val_accuracy improved from 0.82993 to 0.85034, saving model to hybrid_fold_1.keras
#
# Epoch 10: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8953 - loss: 0.5892 - val_accuracy: 0.8503 - val_loss: 0.7160 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8957 - loss: 0.5931
# Epoch 11: val_accuracy improved from 0.85034 to 0.85544, saving model to hybrid_fold_1.keras
#
# Epoch 11: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8987 - loss: 0.5924 - val_accuracy: 0.8554 - val_loss: 0.7015 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8947 - loss: 0.5865
# Epoch 12: val_accuracy did not improve from 0.85544
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8948 - loss: 0.5863 - val_accuracy: 0.8537 - val_loss: 0.6968 - learning_rate: 1.0000e-05
# Score for fold 1: loss of 0.6968; compile_metrics of 85.37%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.4128 - loss: 1.4054
# Epoch 1: val_accuracy improved from None to 0.72789, saving model to hybrid_fold_2.keras
#
# Epoch 1: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 123s 990ms/step - accuracy: 0.5049 - loss: 1.2148 - val_accuracy: 0.7279 - val_loss: 0.8896 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6814 - loss: 0.9529
# Epoch 2: val_accuracy improved from 0.72789 to 0.76701, saving model to hybrid_fold_2.keras
#
# Epoch 2: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.6888 - loss: 0.9365 - val_accuracy: 0.7670 - val_loss: 0.8063 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7490 - loss: 0.8446
# Epoch 3: val_accuracy improved from 0.76701 to 0.79762, saving model to hybrid_fold_2.keras
#
# Epoch 3: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.7599 - loss: 0.8210 - val_accuracy: 0.7976 - val_loss: 0.7455 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7814 - loss: 0.7709
# Epoch 4: val_accuracy improved from 0.79762 to 0.82313, saving model to hybrid_fold_2.keras
#
# Epoch 4: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.7935 - loss: 0.7623 - val_accuracy: 0.8231 - val_loss: 0.7154 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8024 - loss: 0.7319
# Epoch 5: val_accuracy did not improve from 0.82313
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8195 - loss: 0.7108 - val_accuracy: 0.8112 - val_loss: 0.7365 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8221 - loss: 0.7124
# Epoch 6: val_accuracy improved from 0.82313 to 0.82483, saving model to hybrid_fold_2.keras
#
# Epoch 6: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 215ms/step - accuracy: 0.8391 - loss: 0.6867 - val_accuracy: 0.8248 - val_loss: 0.7097 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8613 - loss: 0.6642
# Epoch 7: val_accuracy improved from 0.82483 to 0.83844, saving model to hybrid_fold_2.keras
#
# Epoch 7: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.8621 - loss: 0.6535 - val_accuracy: 0.8384 - val_loss: 0.6904 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8691 - loss: 0.6276
# Epoch 8: val_accuracy did not improve from 0.83844
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.8710 - loss: 0.6272 - val_accuracy: 0.8197 - val_loss: 0.7204 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8928 - loss: 0.6003
# Epoch 9: val_accuracy did not improve from 0.83844
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.8799 - loss: 0.6109 - val_accuracy: 0.8095 - val_loss: 0.7469 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8795 - loss: 0.6023
# Epoch 10: val_accuracy did not improve from 0.83844
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.8859 - loss: 0.5981 - val_accuracy: 0.8367 - val_loss: 0.6938 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8998 - loss: 0.5866
# Epoch 11: val_accuracy improved from 0.83844 to 0.84354, saving model to hybrid_fold_2.keras
#
# Epoch 11: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.8961 - loss: 0.5906 - val_accuracy: 0.8435 - val_loss: 0.6833 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9141 - loss: 0.5825
# Epoch 12: val_accuracy improved from 0.84354 to 0.84864, saving model to hybrid_fold_2.keras
#
# Epoch 12: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.9102 - loss: 0.5817 - val_accuracy: 0.8486 - val_loss: 0.6797 - learning_rate: 1.0000e-05
# Score for fold 2: loss of 0.6797; compile_metrics of 84.86%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.4400 - loss: 1.3353
# Epoch 1: val_accuracy improved from None to 0.70017, saving model to hybrid_fold_3.keras
#
# Epoch 1: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 124s 999ms/step - accuracy: 0.5226 - loss: 1.1967 - val_accuracy: 0.7002 - val_loss: 0.9120 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6661 - loss: 0.9468
# Epoch 2: val_accuracy improved from 0.70017 to 0.76831, saving model to hybrid_fold_3.keras
#
# Epoch 2: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.6949 - loss: 0.9140 - val_accuracy: 0.7683 - val_loss: 0.7971 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7351 - loss: 0.8493
# Epoch 3: val_accuracy improved from 0.76831 to 0.77342, saving model to hybrid_fold_3.keras
#
# Epoch 3: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.7379 - loss: 0.8373 - val_accuracy: 0.7734 - val_loss: 0.7975 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7950 - loss: 0.7701
# Epoch 4: val_accuracy improved from 0.77342 to 0.79216, saving model to hybrid_fold_3.keras
#
# Epoch 4: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 231ms/step - accuracy: 0.8030 - loss: 0.7526 - val_accuracy: 0.7922 - val_loss: 0.7641 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8031 - loss: 0.7441
# Epoch 5: val_accuracy improved from 0.79216 to 0.80750, saving model to hybrid_fold_3.keras
#
# Epoch 5: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8136 - loss: 0.7259 - val_accuracy: 0.8075 - val_loss: 0.7479 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8385 - loss: 0.6630
# Epoch 6: val_accuracy did not improve from 0.80750
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8413 - loss: 0.6711 - val_accuracy: 0.8058 - val_loss: 0.7675 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8485 - loss: 0.6725
# Epoch 7: val_accuracy improved from 0.80750 to 0.83475, saving model to hybrid_fold_3.keras
#
# Epoch 7: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.8540 - loss: 0.6626 - val_accuracy: 0.8348 - val_loss: 0.7068 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8719 - loss: 0.6310
# Epoch 8: val_accuracy improved from 0.83475 to 0.84327, saving model to hybrid_fold_3.keras
#
# Epoch 8: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 220ms/step - accuracy: 0.8732 - loss: 0.6276 - val_accuracy: 0.8433 - val_loss: 0.7177 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8906 - loss: 0.6070
# Epoch 9: val_accuracy did not improve from 0.84327
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.8855 - loss: 0.6130 - val_accuracy: 0.8365 - val_loss: 0.7018 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9012 - loss: 0.5827
# Epoch 10: val_accuracy did not improve from 0.84327
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.8945 - loss: 0.5874 - val_accuracy: 0.8433 - val_loss: 0.7162 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9018 - loss: 0.5719
# Epoch 11: val_accuracy improved from 0.84327 to 0.85179, saving model to hybrid_fold_3.keras
#
# Epoch 11: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 215ms/step - accuracy: 0.8966 - loss: 0.5742 - val_accuracy: 0.8518 - val_loss: 0.6937 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9099 - loss: 0.5660
# Epoch 12: val_accuracy improved from 0.85179 to 0.85520, saving model to hybrid_fold_3.keras
#
# Epoch 12: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.9060 - loss: 0.5719 - val_accuracy: 0.8552 - val_loss: 0.6892 - learning_rate: 1.0000e-05
# Score for fold 3: loss of 0.6892; compile_metrics of 85.52%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.3977 - loss: 1.3736
# Epoch 1: val_accuracy improved from None to 0.68995, saving model to hybrid_fold_4.keras
#
# Epoch 1: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 123s 992ms/step - accuracy: 0.5013 - loss: 1.2154 - val_accuracy: 0.6899 - val_loss: 0.9252 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6673 - loss: 0.9616
# Epoch 2: val_accuracy improved from 0.68995 to 0.76661, saving model to hybrid_fold_4.keras
#
# Epoch 2: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.6894 - loss: 0.9255 - val_accuracy: 0.7666 - val_loss: 0.8118 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7214 - loss: 0.8616
# Epoch 3: val_accuracy improved from 0.76661 to 0.78194, saving model to hybrid_fold_4.keras
#
# Epoch 3: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - accuracy: 0.7468 - loss: 0.8366 - val_accuracy: 0.7819 - val_loss: 0.7715 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7852 - loss: 0.7832
# Epoch 4: val_accuracy improved from 0.78194 to 0.80920, saving model to hybrid_fold_4.keras
#
# Epoch 4: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.7928 - loss: 0.7729 - val_accuracy: 0.8092 - val_loss: 0.7486 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8132 - loss: 0.7333
# Epoch 5: val_accuracy improved from 0.80920 to 0.81090, saving model to hybrid_fold_4.keras
#
# Epoch 5: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.8111 - loss: 0.7319 - val_accuracy: 0.8109 - val_loss: 0.7547 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8403 - loss: 0.6772
# Epoch 6: val_accuracy improved from 0.81090 to 0.83135, saving model to hybrid_fold_4.keras
#
# Epoch 6: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.8485 - loss: 0.6760 - val_accuracy: 0.8313 - val_loss: 0.6975 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8589 - loss: 0.6554
# Epoch 7: val_accuracy improved from 0.83135 to 0.83305, saving model to hybrid_fold_4.keras
#
# Epoch 7: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.8579 - loss: 0.6594 - val_accuracy: 0.8330 - val_loss: 0.6897 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8733 - loss: 0.6285
# Epoch 8: val_accuracy improved from 0.83305 to 0.84497, saving model to hybrid_fold_4.keras
#
# Epoch 8: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.8677 - loss: 0.6335 - val_accuracy: 0.8450 - val_loss: 0.6964 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8708 - loss: 0.6092
# Epoch 9: val_accuracy did not improve from 0.84497
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8821 - loss: 0.6048 - val_accuracy: 0.8416 - val_loss: 0.7251 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8940 - loss: 0.5915
# Epoch 10: val_accuracy improved from 0.84497 to 0.85009, saving model to hybrid_fold_4.keras
#
# Epoch 10: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8894 - loss: 0.5963 - val_accuracy: 0.8501 - val_loss: 0.7230 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9035 - loss: 0.5893
# Epoch 11: val_accuracy improved from 0.85009 to 0.86201, saving model to hybrid_fold_4.keras
#
# Epoch 11: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8953 - loss: 0.5891 - val_accuracy: 0.8620 - val_loss: 0.6761 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9064 - loss: 0.5692
# Epoch 12: val_accuracy improved from 0.86201 to 0.86882, saving model to hybrid_fold_4.keras
#
# Epoch 12: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.9051 - loss: 0.5678 - val_accuracy: 0.8688 - val_loss: 0.6784 - learning_rate: 1.0000e-04
# Score for fold 4: loss of 0.6784; compile_metrics of 86.88%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.4185 - loss: 1.3473
# Epoch 1: val_accuracy improved from None to 0.68654, saving model to hybrid_fold_5.keras
#
# Epoch 1: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 122s 986ms/step - accuracy: 0.5081 - loss: 1.2055 - val_accuracy: 0.6865 - val_loss: 0.9450 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6504 - loss: 0.9795
# Epoch 2: val_accuracy improved from 0.68654 to 0.78194, saving model to hybrid_fold_5.keras
#
# Epoch 2: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.6753 - loss: 0.9506 - val_accuracy: 0.7819 - val_loss: 0.7629 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7608 - loss: 0.8331
# Epoch 3: val_accuracy did not improve from 0.78194
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.7609 - loss: 0.8242 - val_accuracy: 0.7785 - val_loss: 0.7340 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7941 - loss: 0.7556
# Epoch 4: val_accuracy improved from 0.78194 to 0.80920, saving model to hybrid_fold_5.keras
#
# Epoch 4: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.7919 - loss: 0.7596 - val_accuracy: 0.8092 - val_loss: 0.7214 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8106 - loss: 0.7443
# Epoch 5: val_accuracy improved from 0.80920 to 0.83305, saving model to hybrid_fold_5.keras
#
# Epoch 5: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.8098 - loss: 0.7306 - val_accuracy: 0.8330 - val_loss: 0.7172 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8366 - loss: 0.6842
# Epoch 6: val_accuracy did not improve from 0.83305
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8409 - loss: 0.6823 - val_accuracy: 0.8126 - val_loss: 0.7167 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8369 - loss: 0.6731
# Epoch 7: val_accuracy improved from 0.83305 to 0.85009, saving model to hybrid_fold_5.keras
#
# Epoch 7: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.8472 - loss: 0.6720 - val_accuracy: 0.8501 - val_loss: 0.6729 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8827 - loss: 0.6141
# Epoch 8: val_accuracy improved from 0.85009 to 0.86031, saving model to hybrid_fold_5.keras
#
# Epoch 8: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.8826 - loss: 0.6207 - val_accuracy: 0.8603 - val_loss: 0.6747 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8783 - loss: 0.6058
# Epoch 9: val_accuracy improved from 0.86031 to 0.87223, saving model to hybrid_fold_5.keras
#
# Epoch 9: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.8749 - loss: 0.6101 - val_accuracy: 0.8722 - val_loss: 0.6268 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8953 - loss: 0.5984
# Epoch 10: val_accuracy did not improve from 0.87223
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.8957 - loss: 0.5972 - val_accuracy: 0.8688 - val_loss: 0.6444 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8889 - loss: 0.5904
# Epoch 11: val_accuracy did not improve from 0.87223
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.8923 - loss: 0.5861 - val_accuracy: 0.8518 - val_loss: 0.6753 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9171 - loss: 0.5546
# Epoch 12: val_accuracy did not improve from 0.87223
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9102 - loss: 0.5618 - val_accuracy: 0.8705 - val_loss: 0.6268 - learning_rate: 1.0000e-05
# Score for fold 5: loss of 0.6268; compile_metrics of 87.05%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.6968 - Accuracy: 85.37%
# > Fold 2 - Loss: 0.6797 - Accuracy: 84.86%
# > Fold 3 - Loss: 0.6892 - Accuracy: 85.52%
# > Fold 4 - Loss: 0.6784 - Accuracy: 86.88%
# > Fold 5 - Loss: 0.6268 - Accuracy: 87.05%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 85.94% (+- 0.87%)
# > Loss: 0.6742
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# model = tf.keras.models.load_model('efficientnetB0_fold_5.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.88      0.90      0.89        93
#         no_tumor       0.94      0.90      0.92        51
# meningioma_tumor       0.91      0.72      0.80        96
#  pituitary_tumor       0.77      0.94      0.85        87
#
#         accuracy                           0.86       327
#        macro avg       0.87      0.87      0.87       327
#     weighted avg       0.87      0.86      0.86       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(10).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
