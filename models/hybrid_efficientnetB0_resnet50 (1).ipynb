# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:13<00:00, 62.44it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:08<00:00, 47.86it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:12<00:00, 64.67it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:13<00:00, 61.01it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:01<00:00, 56.01it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:02<00:00, 48.21it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:02<00:00, 57.16it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:23<00:00,  3.11it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: Hybrid (ResNet50 + EfficientNetB0)

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    # Shared input layer
    input_layer = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    # Base Model 1: ResNet50
    resnet50_base = tf.keras.applications.ResNet50(weights='imagenet', include_top=False)
    resnet50_base.trainable = False
    for layer in resnet50_base.layers[:-20]:
        layer.trainable = False
    resnet_out = resnet50_base(input_layer)
    resnet_pool = layers.GlobalAveragePooling2D()(resnet_out)

    # Base Model 2: EfficientNetB0
    efficientnet_base = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False)
    efficientnet_base.trainable = False
    for layer in efficientnet_base.layers[:-20]:
        layer.trainable = False
    effnet_out = efficientnet_base(input_layer)
    effnet_pool = layers.GlobalAveragePooling2D()(effnet_out)

    # Concatenate features from both models
    merged = layers.Concatenate()([resnet_pool, effnet_pool])

    # Custom classification head
    x = layers.Dense(1024, activation='relu')(merged)
    x = layers.Dropout(0.4)(x)

    # Output layer
    output_layer = layers.Dense(len(labels), activation='softmax')(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"hybrid_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr],
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.4757 - loss: 1.3191
# Epoch 1: val_accuracy improved from None to 0.75170, saving model to hybrid_fold_1.keras
#
# Epoch 1: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 92s 753ms/step - accuracy: 0.5973 - loss: 0.9872 - val_accuracy: 0.7517 - val_loss: 0.6441 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7736 - loss: 0.6202
# Epoch 2: val_accuracy improved from 0.75170 to 0.78741, saving model to hybrid_fold_1.keras
#
# Epoch 2: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.7769 - loss: 0.5940 - val_accuracy: 0.7874 - val_loss: 0.5506 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7899 - loss: 0.5091
# Epoch 3: val_accuracy improved from 0.78741 to 0.81803, saving model to hybrid_fold_1.keras
#
# Epoch 3: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8003 - loss: 0.5037 - val_accuracy: 0.8180 - val_loss: 0.4636 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8407 - loss: 0.4226
# Epoch 4: val_accuracy did not improve from 0.81803
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.8272 - loss: 0.4493 - val_accuracy: 0.8112 - val_loss: 0.5027 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8318 - loss: 0.4325
# Epoch 5: val_accuracy improved from 0.81803 to 0.82993, saving model to hybrid_fold_1.keras
#
# Epoch 5: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 209ms/step - accuracy: 0.8455 - loss: 0.4028 - val_accuracy: 0.8299 - val_loss: 0.4768 - learning_rate: 1.0000e-04
# Epoch 6/12
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8647 - loss: 0.3405
# Epoch 6: val_accuracy improved from 0.82993 to 0.85204, saving model to hybrid_fold_1.keras
#
# Epoch 6: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 234ms/step - accuracy: 0.8668 - loss: 0.3431 - val_accuracy: 0.8520 - val_loss: 0.4141 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8767 - loss: 0.3535
# Epoch 7: val_accuracy improved from 0.85204 to 0.86905, saving model to hybrid_fold_1.keras
#
# Epoch 7: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.8723 - loss: 0.3496 - val_accuracy: 0.8690 - val_loss: 0.4015 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8754 - loss: 0.3426
# Epoch 8: val_accuracy improved from 0.86905 to 0.87415, saving model to hybrid_fold_1.keras
#
# Epoch 8: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.8782 - loss: 0.3309 - val_accuracy: 0.8741 - val_loss: 0.3680 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8690 - loss: 0.3261
# Epoch 9: val_accuracy did not improve from 0.87415
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.8817 - loss: 0.3120 - val_accuracy: 0.8605 - val_loss: 0.4084 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8974 - loss: 0.2789
# Epoch 10: val_accuracy did not improve from 0.87415
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.8906 - loss: 0.2882 - val_accuracy: 0.8571 - val_loss: 0.4185 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9211 - loss: 0.2500
# Epoch 11: val_accuracy improved from 0.87415 to 0.87585, saving model to hybrid_fold_1.keras
#
# Epoch 11: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9161 - loss: 0.2516 - val_accuracy: 0.8759 - val_loss: 0.3792 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9141 - loss: 0.2388
# Epoch 12: val_accuracy did not improve from 0.87585
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9119 - loss: 0.2436 - val_accuracy: 0.8759 - val_loss: 0.3793 - learning_rate: 1.0000e-05
# Score for fold 1: loss of 0.3793; compile_metrics of 87.59%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5089 - loss: 1.2426
# Epoch 1: val_accuracy improved from None to 0.74830, saving model to hybrid_fold_2.keras
#
# Epoch 1: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 69s 576ms/step - accuracy: 0.6322 - loss: 0.9210 - val_accuracy: 0.7483 - val_loss: 0.5836 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7693 - loss: 0.6198
# Epoch 2: val_accuracy improved from 0.74830 to 0.78741, saving model to hybrid_fold_2.keras
#
# Epoch 2: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.7799 - loss: 0.5762 - val_accuracy: 0.7874 - val_loss: 0.5610 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8115 - loss: 0.4975
# Epoch 3: val_accuracy did not improve from 0.78741
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 181ms/step - accuracy: 0.8008 - loss: 0.5016 - val_accuracy: 0.7653 - val_loss: 0.5947 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8309 - loss: 0.4454
# Epoch 4: val_accuracy improved from 0.78741 to 0.80102, saving model to hybrid_fold_2.keras
#
# Epoch 4: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.8395 - loss: 0.4393 - val_accuracy: 0.8010 - val_loss: 0.5620 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8379 - loss: 0.3931
# Epoch 5: val_accuracy improved from 0.80102 to 0.82483, saving model to hybrid_fold_2.keras
#
# Epoch 5: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.8408 - loss: 0.3991 - val_accuracy: 0.8248 - val_loss: 0.5055 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8655 - loss: 0.3577
# Epoch 6: val_accuracy did not improve from 0.82483
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8650 - loss: 0.3585 - val_accuracy: 0.8061 - val_loss: 0.4831 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8838 - loss: 0.3142
# Epoch 7: val_accuracy improved from 0.82483 to 0.86905, saving model to hybrid_fold_2.keras
#
# Epoch 7: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8770 - loss: 0.3402 - val_accuracy: 0.8690 - val_loss: 0.3552 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8673 - loss: 0.3487
# Epoch 8: val_accuracy did not improve from 0.86905
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.8736 - loss: 0.3383 - val_accuracy: 0.8503 - val_loss: 0.4268 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9031 - loss: 0.2790
# Epoch 9: val_accuracy did not improve from 0.86905
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9004 - loss: 0.2931 - val_accuracy: 0.8452 - val_loss: 0.3825 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9075 - loss: 0.2773
# Epoch 10: val_accuracy did not improve from 0.86905
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9072 - loss: 0.2783 - val_accuracy: 0.8656 - val_loss: 0.3671 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9099 - loss: 0.2457
# Epoch 11: val_accuracy did not improve from 0.86905
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.9059 - loss: 0.2551 - val_accuracy: 0.8639 - val_loss: 0.3634 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9166 - loss: 0.2527
# Epoch 12: val_accuracy did not improve from 0.86905
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9187 - loss: 0.2464 - val_accuracy: 0.8605 - val_loss: 0.3682 - learning_rate: 1.0000e-06
# Score for fold 2: loss of 0.3682; compile_metrics of 86.05%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.5418 - loss: 1.1706
# Epoch 1: val_accuracy improved from None to 0.75128, saving model to hybrid_fold_3.keras
#
# Epoch 1: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 83s 771ms/step - accuracy: 0.6523 - loss: 0.8968 - val_accuracy: 0.7513 - val_loss: 0.6267 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7726 - loss: 0.5842
# Epoch 2: val_accuracy improved from 0.75128 to 0.76831, saving model to hybrid_fold_3.keras
#
# Epoch 2: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.7817 - loss: 0.5729 - val_accuracy: 0.7683 - val_loss: 0.5890 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8158 - loss: 0.4887
# Epoch 3: val_accuracy improved from 0.76831 to 0.81601, saving model to hybrid_fold_3.keras
#
# Epoch 3: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.8200 - loss: 0.4731 - val_accuracy: 0.8160 - val_loss: 0.5072 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8438 - loss: 0.4076
# Epoch 4: val_accuracy did not improve from 0.81601
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 181ms/step - accuracy: 0.8370 - loss: 0.4242 - val_accuracy: 0.7734 - val_loss: 0.6335 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8491 - loss: 0.3974
# Epoch 5: val_accuracy did not improve from 0.81601
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 177ms/step - accuracy: 0.8455 - loss: 0.3999 - val_accuracy: 0.8143 - val_loss: 0.5078 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8531 - loss: 0.3769
# Epoch 6: val_accuracy improved from 0.81601 to 0.85179, saving model to hybrid_fold_3.keras
#
# Epoch 6: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.8689 - loss: 0.3511 - val_accuracy: 0.8518 - val_loss: 0.4204 - learning_rate: 1.0000e-05
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8846 - loss: 0.3093
# Epoch 7: val_accuracy did not improve from 0.85179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.8762 - loss: 0.3326 - val_accuracy: 0.8484 - val_loss: 0.4169 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8656 - loss: 0.3426
# Epoch 8: val_accuracy did not improve from 0.85179
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.8774 - loss: 0.3261 - val_accuracy: 0.8433 - val_loss: 0.4182 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8907 - loss: 0.3183
# Epoch 9: val_accuracy did not improve from 0.85179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.8936 - loss: 0.3153 - val_accuracy: 0.8399 - val_loss: 0.4223 - learning_rate: 1.0000e-06
# Epoch 10/12
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8798 - loss: 0.3198
# Epoch 10: val_accuracy did not improve from 0.85179
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8843 - loss: 0.3168 - val_accuracy: 0.8399 - val_loss: 0.4234 - learning_rate: 1.0000e-06
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8755 - loss: 0.3212
# Epoch 11: val_accuracy did not improve from 0.85179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.8791 - loss: 0.3201 - val_accuracy: 0.8399 - val_loss: 0.4233 - learning_rate: 1.0000e-07
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8922 - loss: 0.2976
# Epoch 12: val_accuracy did not improve from 0.85179
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8923 - loss: 0.2969 - val_accuracy: 0.8399 - val_loss: 0.4233 - learning_rate: 1.0000e-07
# Score for fold 3: loss of 0.4233; compile_metrics of 83.99%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5116 - loss: 1.2253
# Epoch 1: val_accuracy improved from None to 0.72743, saving model to hybrid_fold_4.keras
#
# Epoch 1: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 72s 581ms/step - accuracy: 0.6281 - loss: 0.9507 - val_accuracy: 0.7274 - val_loss: 0.6843 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7751 - loss: 0.6011
# Epoch 2: val_accuracy improved from 0.72743 to 0.80409, saving model to hybrid_fold_4.keras
#
# Epoch 2: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.7736 - loss: 0.5940 - val_accuracy: 0.8041 - val_loss: 0.5523 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8008 - loss: 0.5335
# Epoch 3: val_accuracy did not improve from 0.80409
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8111 - loss: 0.5042 - val_accuracy: 0.7836 - val_loss: 0.5409 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8230 - loss: 0.4612
# Epoch 4: val_accuracy improved from 0.80409 to 0.84838, saving model to hybrid_fold_4.keras
#
# Epoch 4: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.8336 - loss: 0.4400 - val_accuracy: 0.8484 - val_loss: 0.4787 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8535 - loss: 0.3856
# Epoch 5: val_accuracy did not improve from 0.84838
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.8562 - loss: 0.3843 - val_accuracy: 0.8365 - val_loss: 0.4569 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8625 - loss: 0.3643
# Epoch 6: val_accuracy did not improve from 0.84838
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.8655 - loss: 0.3499 - val_accuracy: 0.7973 - val_loss: 0.5479 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8696 - loss: 0.3332
# Epoch 7: val_accuracy improved from 0.84838 to 0.85690, saving model to hybrid_fold_4.keras
#
# Epoch 7: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8736 - loss: 0.3351 - val_accuracy: 0.8569 - val_loss: 0.4343 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8899 - loss: 0.3050
# Epoch 8: val_accuracy did not improve from 0.85690
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8911 - loss: 0.3024 - val_accuracy: 0.8535 - val_loss: 0.4387 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8870 - loss: 0.3351
# Epoch 9: val_accuracy improved from 0.85690 to 0.86031, saving model to hybrid_fold_4.keras
#
# Epoch 9: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.8864 - loss: 0.3251 - val_accuracy: 0.8603 - val_loss: 0.4223 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8752 - loss: 0.3248
# Epoch 10: val_accuracy did not improve from 0.86031
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8851 - loss: 0.3017 - val_accuracy: 0.8603 - val_loss: 0.4273 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8885 - loss: 0.3181
# Epoch 11: val_accuracy did not improve from 0.86031
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.8915 - loss: 0.3035 - val_accuracy: 0.8569 - val_loss: 0.4313 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9013 - loss: 0.2806
# Epoch 12: val_accuracy did not improve from 0.86031
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.8974 - loss: 0.2893 - val_accuracy: 0.8569 - val_loss: 0.4301 - learning_rate: 1.0000e-06
# Score for fold 4: loss of 0.4301; compile_metrics of 85.69%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5446 - loss: 1.1902
# Epoch 1: val_accuracy improved from None to 0.77002, saving model to hybrid_fold_5.keras
#
# Epoch 1: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 70s 582ms/step - accuracy: 0.6328 - loss: 0.9321 - val_accuracy: 0.7700 - val_loss: 0.5513 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7737 - loss: 0.5919
# Epoch 2: val_accuracy improved from 0.77002 to 0.77172, saving model to hybrid_fold_5.keras
#
# Epoch 2: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.7813 - loss: 0.5857 - val_accuracy: 0.7717 - val_loss: 0.5077 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8192 - loss: 0.4636
# Epoch 3: val_accuracy improved from 0.77172 to 0.80068, saving model to hybrid_fold_5.keras
#
# Epoch 3: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.8111 - loss: 0.4759 - val_accuracy: 0.8007 - val_loss: 0.4878 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8493 - loss: 0.4387
# Epoch 4: val_accuracy improved from 0.80068 to 0.81942, saving model to hybrid_fold_5.keras
#
# Epoch 4: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.8404 - loss: 0.4392 - val_accuracy: 0.8194 - val_loss: 0.4140 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8285 - loss: 0.4354
# Epoch 5: val_accuracy did not improve from 0.81942
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8370 - loss: 0.4171 - val_accuracy: 0.8177 - val_loss: 0.4397 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8635 - loss: 0.3424
# Epoch 6: val_accuracy improved from 0.81942 to 0.85179, saving model to hybrid_fold_5.keras
#
# Epoch 6: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.8574 - loss: 0.3654 - val_accuracy: 0.8518 - val_loss: 0.3656 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8723 - loss: 0.3506
# Epoch 7: val_accuracy did not improve from 0.85179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.8791 - loss: 0.3412 - val_accuracy: 0.8365 - val_loss: 0.3987 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8824 - loss: 0.3404
# Epoch 8: val_accuracy did not improve from 0.85179
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.8796 - loss: 0.3413 - val_accuracy: 0.8518 - val_loss: 0.3653 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8849 - loss: 0.2985
# Epoch 9: val_accuracy did not improve from 0.85179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.8864 - loss: 0.2914 - val_accuracy: 0.8484 - val_loss: 0.3828 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9025 - loss: 0.2749
# Epoch 10: val_accuracy improved from 0.85179 to 0.85349, saving model to hybrid_fold_5.keras
#
# Epoch 10: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.9043 - loss: 0.2691 - val_accuracy: 0.8535 - val_loss: 0.3607 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9162 - loss: 0.2553
# Epoch 11: val_accuracy did not improve from 0.85349
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.9094 - loss: 0.2638 - val_accuracy: 0.8467 - val_loss: 0.3656 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9048 - loss: 0.2816
# Epoch 12: val_accuracy did not improve from 0.85349
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9017 - loss: 0.2713 - val_accuracy: 0.8433 - val_loss: 0.3723 - learning_rate: 1.0000e-05
# Score for fold 5: loss of 0.3723; compile_metrics of 84.33%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.3793 - Accuracy: 87.59%
# > Fold 2 - Loss: 0.3682 - Accuracy: 86.05%
# > Fold 3 - Loss: 0.4233 - Accuracy: 83.99%
# > Fold 4 - Loss: 0.4301 - Accuracy: 85.69%
# > Fold 5 - Loss: 0.3723 - Accuracy: 84.33%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 85.53% (+- 1.29%)
# > Loss: 0.3947
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
model = tf.keras.models.load_model('hybrid_fold_2.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.93      0.85      0.89        93
#         no_tumor       0.94      0.90      0.92        51
# meningioma_tumor       0.81      0.81      0.81        96
#  pituitary_tumor       0.86      0.95      0.90        87
#
#         accuracy                           0.87       327
#        macro avg       0.88      0.88      0.88       327
#     weighted avg       0.88      0.87      0.87       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Save the final trained model
model.save('/content/gdrive/MyDrive/brain_tumor/models/efficientnetb0_resnet50_model.keras.keras')

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(10).jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
