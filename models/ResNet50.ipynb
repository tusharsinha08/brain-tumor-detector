# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:16<00:00, 50.14it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:04<00:00, 81.90it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:16<00:00, 49.18it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:17<00:00, 47.14it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:01<00:00, 63.64it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:01<00:00, 73.50it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:01<00:00, 65.38it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:18<00:00,  4.09it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: ResNet50

# %%
from sklearn.model_selection import KFold
import tensorflow as tf

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
    )

    # Freeze most layers
    for layer in base_model.layers[:-30]:
        layer.trainable = False

    for layer in base_model.layers[-30:]:
        layer.trainable = True

    x = base_model.output

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.5)(x)

    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    outputs = tf.keras.layers.Dense(4, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=base_model.input, outputs=outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"resnet50_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr]
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.3961 - loss: 1.8800
# Epoch 1: val_accuracy improved from None to 0.66497, saving model to resnet50_fold_1.keras
#
# Epoch 1: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.5160 - loss: 1.4407 - val_accuracy: 0.6650 - val_loss: 1.0548 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7204 - loss: 0.8159
# Epoch 2: val_accuracy improved from 0.66497 to 0.79082, saving model to resnet50_fold_1.keras
#
# Epoch 2: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.7373 - loss: 0.7560 - val_accuracy: 0.7908 - val_loss: 0.7757 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7902 - loss: 0.5704
# Epoch 3: val_accuracy improved from 0.79082 to 0.84864, saving model to resnet50_fold_1.keras
#
# Epoch 3: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8012 - loss: 0.5520 - val_accuracy: 0.8486 - val_loss: 0.5677 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8352 - loss: 0.4569
# Epoch 4: val_accuracy did not improve from 0.84864
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.8357 - loss: 0.4621 - val_accuracy: 0.8452 - val_loss: 0.6220 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8447 - loss: 0.4336
# Epoch 5: val_accuracy improved from 0.84864 to 0.89796, saving model to resnet50_fold_1.keras
#
# Epoch 5: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8531 - loss: 0.4168 - val_accuracy: 0.8980 - val_loss: 0.5036 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8868 - loss: 0.3109
# Epoch 6: val_accuracy did not improve from 0.89796
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.8923 - loss: 0.3157 - val_accuracy: 0.8759 - val_loss: 0.4868 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8924 - loss: 0.2955
# Epoch 7: val_accuracy did not improve from 0.89796
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.8880 - loss: 0.3104 - val_accuracy: 0.8741 - val_loss: 0.5561 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8966 - loss: 0.2587
# Epoch 8: val_accuracy did not improve from 0.89796
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.8991 - loss: 0.2672 - val_accuracy: 0.8946 - val_loss: 0.4872 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9028 - loss: 0.2538
# Epoch 9: val_accuracy improved from 0.89796 to 0.90136, saving model to resnet50_fold_1.keras
#
# Epoch 9: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.9093 - loss: 0.2527 - val_accuracy: 0.9014 - val_loss: 0.4452 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9304 - loss: 0.2004
# Epoch 10: val_accuracy improved from 0.90136 to 0.90306, saving model to resnet50_fold_1.keras
#
# Epoch 10: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9238 - loss: 0.2318 - val_accuracy: 0.9031 - val_loss: 0.4225 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9202 - loss: 0.2166
# Epoch 11: val_accuracy did not improve from 0.90306
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9246 - loss: 0.2180 - val_accuracy: 0.8997 - val_loss: 0.4295 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9174 - loss: 0.2027
# Epoch 12: val_accuracy improved from 0.90306 to 0.90646, saving model to resnet50_fold_1.keras
#
# Epoch 12: finished saving model to resnet50_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9170 - loss: 0.2105 - val_accuracy: 0.9065 - val_loss: 0.3781 - learning_rate: 1.0000e-05
# Score for fold 1: loss of 0.3781; compile_metrics of 90.65%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.4269 - loss: 1.6342
# Epoch 1: val_accuracy improved from None to 0.65476, saving model to resnet50_fold_2.keras
#
# Epoch 1: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 47s 386ms/step - accuracy: 0.5407 - loss: 1.2789 - val_accuracy: 0.6548 - val_loss: 0.9829 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7411 - loss: 0.7209
# Epoch 2: val_accuracy improved from 0.65476 to 0.76020, saving model to resnet50_fold_2.keras
#
# Epoch 2: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.7493 - loss: 0.7147 - val_accuracy: 0.7602 - val_loss: 0.6619 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7844 - loss: 0.5915
# Epoch 3: val_accuracy improved from 0.76020 to 0.84184, saving model to resnet50_fold_2.keras
#
# Epoch 3: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8012 - loss: 0.5593 - val_accuracy: 0.8418 - val_loss: 0.4799 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8356 - loss: 0.4736
# Epoch 4: val_accuracy improved from 0.84184 to 0.86224, saving model to resnet50_fold_2.keras
#
# Epoch 4: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8404 - loss: 0.4615 - val_accuracy: 0.8622 - val_loss: 0.5798 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8442 - loss: 0.4297
# Epoch 5: val_accuracy did not improve from 0.86224
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.8616 - loss: 0.3870 - val_accuracy: 0.8469 - val_loss: 0.5915 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8894 - loss: 0.3071
# Epoch 6: val_accuracy did not improve from 0.86224
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.8808 - loss: 0.3332 - val_accuracy: 0.8537 - val_loss: 0.5784 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8864 - loss: 0.2900
# Epoch 7: val_accuracy improved from 0.86224 to 0.87075, saving model to resnet50_fold_2.keras
#
# Epoch 7: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8923 - loss: 0.2886 - val_accuracy: 0.8707 - val_loss: 0.4656 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9068 - loss: 0.2494
# Epoch 8: val_accuracy improved from 0.87075 to 0.87925, saving model to resnet50_fold_2.keras
#
# Epoch 8: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9051 - loss: 0.2695 - val_accuracy: 0.8793 - val_loss: 0.4307 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9228 - loss: 0.2295
# Epoch 9: val_accuracy improved from 0.87925 to 0.88605, saving model to resnet50_fold_2.keras
#
# Epoch 9: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.9140 - loss: 0.2405 - val_accuracy: 0.8861 - val_loss: 0.3937 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9130 - loss: 0.2451
# Epoch 10: val_accuracy improved from 0.88605 to 0.88946, saving model to resnet50_fold_2.keras
#
# Epoch 10: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9093 - loss: 0.2524 - val_accuracy: 0.8895 - val_loss: 0.4041 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9097 - loss: 0.2318
# Epoch 11: val_accuracy improved from 0.88946 to 0.89116, saving model to resnet50_fold_2.keras
#
# Epoch 11: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.9102 - loss: 0.2440 - val_accuracy: 0.8912 - val_loss: 0.3878 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9166 - loss: 0.2188
# Epoch 12: val_accuracy improved from 0.89116 to 0.89966, saving model to resnet50_fold_2.keras
#
# Epoch 12: finished saving model to resnet50_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9217 - loss: 0.2189 - val_accuracy: 0.8997 - val_loss: 0.3745 - learning_rate: 1.0000e-05
# Score for fold 2: loss of 0.3745; compile_metrics of 89.97%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4489 - loss: 1.5388
# Epoch 1: val_accuracy improved from None to 0.78876, saving model to resnet50_fold_3.keras
#
# Epoch 1: finished saving model to resnet50_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 50s 422ms/step - accuracy: 0.5694 - loss: 1.1760 - val_accuracy: 0.7888 - val_loss: 0.5596 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7528 - loss: 0.6798
# Epoch 2: val_accuracy improved from 0.78876 to 0.83646, saving model to resnet50_fold_3.keras
#
# Epoch 2: finished saving model to resnet50_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.7643 - loss: 0.6818 - val_accuracy: 0.8365 - val_loss: 0.5436 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8033 - loss: 0.5210
# Epoch 3: val_accuracy did not improve from 0.83646
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.8191 - loss: 0.4943 - val_accuracy: 0.8211 - val_loss: 0.7168 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8446 - loss: 0.4207
# Epoch 4: val_accuracy improved from 0.83646 to 0.84497, saving model to resnet50_fold_3.keras
#
# Epoch 4: finished saving model to resnet50_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.8523 - loss: 0.3990 - val_accuracy: 0.8450 - val_loss: 0.4965 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8762 - loss: 0.3522
# Epoch 5: val_accuracy improved from 0.84497 to 0.86371, saving model to resnet50_fold_3.keras
#
# Epoch 5: finished saving model to resnet50_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8749 - loss: 0.3438 - val_accuracy: 0.8637 - val_loss: 0.5244 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8845 - loss: 0.3242
# Epoch 6: val_accuracy did not improve from 0.86371
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.8851 - loss: 0.3207 - val_accuracy: 0.8416 - val_loss: 0.5338 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8935 - loss: 0.3230
# Epoch 7: val_accuracy improved from 0.86371 to 0.86882, saving model to resnet50_fold_3.keras
#
# Epoch 7: finished saving model to resnet50_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.8940 - loss: 0.3042 - val_accuracy: 0.8688 - val_loss: 0.4666 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9056 - loss: 0.2331
# Epoch 8: val_accuracy improved from 0.86882 to 0.87734, saving model to resnet50_fold_3.keras
#
# Epoch 8: finished saving model to resnet50_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9060 - loss: 0.2368 - val_accuracy: 0.8773 - val_loss: 0.5623 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9289 - loss: 0.2100
# Epoch 9: val_accuracy did not improve from 0.87734
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9209 - loss: 0.2423 - val_accuracy: 0.8416 - val_loss: 0.6931 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9198 - loss: 0.2241
# Epoch 10: val_accuracy did not improve from 0.87734
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9115 - loss: 0.2460 - val_accuracy: 0.8773 - val_loss: 0.3835 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9229 - loss: 0.2148
# Epoch 11: val_accuracy did not improve from 0.87734
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.9234 - loss: 0.2100 - val_accuracy: 0.8739 - val_loss: 0.3838 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9465 - loss: 0.1324
# Epoch 12: val_accuracy did not improve from 0.87734
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.9426 - loss: 0.1483 - val_accuracy: 0.8722 - val_loss: 0.4007 - learning_rate: 1.0000e-05
# Score for fold 3: loss of 0.4007; compile_metrics of 87.22%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.4345 - loss: 1.6206
# Epoch 1: val_accuracy improved from None to 0.58773, saving model to resnet50_fold_4.keras
#
# Epoch 1: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 46s 386ms/step - accuracy: 0.5447 - loss: 1.2908 - val_accuracy: 0.5877 - val_loss: 1.2258 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7234 - loss: 0.7669
# Epoch 2: val_accuracy improved from 0.58773 to 0.73254, saving model to resnet50_fold_4.keras
#
# Epoch 2: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.7302 - loss: 0.7437 - val_accuracy: 0.7325 - val_loss: 0.9519 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7830 - loss: 0.6078
# Epoch 3: val_accuracy improved from 0.73254 to 0.83646, saving model to resnet50_fold_4.keras
#
# Epoch 3: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.7957 - loss: 0.5635 - val_accuracy: 0.8365 - val_loss: 0.5695 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8426 - loss: 0.4318
# Epoch 4: val_accuracy improved from 0.83646 to 0.85349, saving model to resnet50_fold_4.keras
#
# Epoch 4: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8455 - loss: 0.4403 - val_accuracy: 0.8535 - val_loss: 0.5499 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8605 - loss: 0.3918
# Epoch 5: val_accuracy improved from 0.85349 to 0.85690, saving model to resnet50_fold_4.keras
#
# Epoch 5: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8591 - loss: 0.3993 - val_accuracy: 0.8569 - val_loss: 0.5129 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8631 - loss: 0.3893
# Epoch 6: val_accuracy improved from 0.85690 to 0.87905, saving model to resnet50_fold_4.keras
#
# Epoch 6: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8715 - loss: 0.3675 - val_accuracy: 0.8790 - val_loss: 0.4622 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8926 - loss: 0.3125
# Epoch 7: val_accuracy did not improve from 0.87905
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.8945 - loss: 0.2994 - val_accuracy: 0.8603 - val_loss: 0.5912 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8923 - loss: 0.3039
# Epoch 8: val_accuracy improved from 0.87905 to 0.88586, saving model to resnet50_fold_4.keras
#
# Epoch 8: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9021 - loss: 0.2798 - val_accuracy: 0.8859 - val_loss: 0.4672 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9103 - loss: 0.2456
# Epoch 9: val_accuracy did not improve from 0.88586
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9102 - loss: 0.2493 - val_accuracy: 0.8859 - val_loss: 0.4583 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9256 - loss: 0.1997
# Epoch 10: val_accuracy improved from 0.88586 to 0.90801, saving model to resnet50_fold_4.keras
#
# Epoch 10: finished saving model to resnet50_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9251 - loss: 0.1998 - val_accuracy: 0.9080 - val_loss: 0.3499 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9304 - loss: 0.2022
# Epoch 11: val_accuracy did not improve from 0.90801
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.9238 - loss: 0.2294 - val_accuracy: 0.8961 - val_loss: 0.4641 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9302 - loss: 0.2123
# Epoch 12: val_accuracy did not improve from 0.90801
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9234 - loss: 0.2279 - val_accuracy: 0.8739 - val_loss: 0.5158 - learning_rate: 1.0000e-04
# Score for fold 4: loss of 0.5158; compile_metrics of 87.39%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.4678 - loss: 1.5499
# Epoch 1: val_accuracy improved from None to 0.60477, saving model to resnet50_fold_5.keras
#
# Epoch 1: finished saving model to resnet50_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 48s 382ms/step - accuracy: 0.5736 - loss: 1.2410 - val_accuracy: 0.6048 - val_loss: 1.0847 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7332 - loss: 0.8094
# Epoch 2: val_accuracy improved from 0.60477 to 0.75980, saving model to resnet50_fold_5.keras
#
# Epoch 2: finished saving model to resnet50_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.7574 - loss: 0.7237 - val_accuracy: 0.7598 - val_loss: 0.7832 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7941 - loss: 0.5657
# Epoch 3: val_accuracy improved from 0.75980 to 0.79046, saving model to resnet50_fold_5.keras
#
# Epoch 3: finished saving model to resnet50_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8034 - loss: 0.5439 - val_accuracy: 0.7905 - val_loss: 0.6983 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8360 - loss: 0.4282
# Epoch 4: val_accuracy improved from 0.79046 to 0.84327, saving model to resnet50_fold_5.keras
#
# Epoch 4: finished saving model to resnet50_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.8409 - loss: 0.4311 - val_accuracy: 0.8433 - val_loss: 0.4861 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8722 - loss: 0.3775
# Epoch 5: val_accuracy improved from 0.84327 to 0.87905, saving model to resnet50_fold_5.keras
#
# Epoch 5: finished saving model to resnet50_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.8694 - loss: 0.3634 - val_accuracy: 0.8790 - val_loss: 0.3424 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8793 - loss: 0.3316
# Epoch 6: val_accuracy improved from 0.87905 to 0.89267, saving model to resnet50_fold_5.keras
#
# Epoch 6: finished saving model to resnet50_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.8847 - loss: 0.3136 - val_accuracy: 0.8927 - val_loss: 0.3204 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9130 - loss: 0.2601
# Epoch 7: val_accuracy did not improve from 0.89267
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9064 - loss: 0.2794 - val_accuracy: 0.8399 - val_loss: 0.5183 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8967 - loss: 0.2971
# Epoch 8: val_accuracy did not improve from 0.89267
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.8919 - loss: 0.3018 - val_accuracy: 0.8807 - val_loss: 0.3736 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9178 - loss: 0.2249
# Epoch 9: val_accuracy did not improve from 0.89267
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9196 - loss: 0.2194 - val_accuracy: 0.8859 - val_loss: 0.3447 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9223 - loss: 0.2117
# Epoch 10: val_accuracy did not improve from 0.89267
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9247 - loss: 0.2120 - val_accuracy: 0.8910 - val_loss: 0.3162 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9215 - loss: 0.1990
# Epoch 11: val_accuracy did not improve from 0.89267
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.9251 - loss: 0.1942 - val_accuracy: 0.8910 - val_loss: 0.3110 - learning_rate: 1.0000e-06
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9140 - loss: 0.2186
# Epoch 12: val_accuracy did not improve from 0.89267
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.9191 - loss: 0.2081 - val_accuracy: 0.8910 - val_loss: 0.3137 - learning_rate: 1.0000e-06
# Score for fold 5: loss of 0.3137; compile_metrics of 89.10%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.3781 - Accuracy: 90.65%
# > Fold 2 - Loss: 0.3745 - Accuracy: 89.97%
# > Fold 3 - Loss: 0.4007 - Accuracy: 87.22%
# > Fold 4 - Loss: 0.5158 - Accuracy: 87.39%
# > Fold 5 - Loss: 0.3137 - Accuracy: 89.10%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 88.87% (+- 1.36%)
# > Loss: 0.3965
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
# model = tf.keras.models.load_model('efficientnetB0_fold_5.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 513ms/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.94      0.94      0.94        93
#         no_tumor       0.98      1.00      0.99        51
# meningioma_tumor       0.91      0.75      0.82        96
#  pituitary_tumor       0.82      0.97      0.88        87
#
#         accuracy                           0.90       327
#        macro avg       0.91      0.91      0.91       327
#     weighted avg       0.90      0.90      0.90       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
