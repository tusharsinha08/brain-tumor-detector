# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:03<00:00, 256.33it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [01:26<00:00,  4.54it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [03:07<00:00,  4.38it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [03:07<00:00,  4.42it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:22<00:00,  4.54it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:19<00:00,  5.41it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:25<00:00,  4.46it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:16<00:00,  4.60it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: Hybrid (ResNet50 + EfficientNetB0)

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    # Shared input layer
    input_layer = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    # Base Model 1: ResNet50
    resnet50_base = tf.keras.applications.ResNet50(weights='imagenet', include_top=False)
    resnet50_base.trainable = True
    for layer in resnet50_base.layers[:-20]:
        layer.trainable = False
    resnet_out = resnet50_base(input_layer)
    resnet_pool = layers.GlobalAveragePooling2D()(resnet_out)

    # Base Model 2: EfficientNetB0
    efficientnet_base = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False)
    efficientnet_base.trainable = True
    for layer in efficientnet_base.layers[:-20]:
        layer.trainable = False
    effnet_out = efficientnet_base(input_layer)
    effnet_pool = layers.GlobalAveragePooling2D()(effnet_out)

    # Concatenate features from both models
    merged = layers.Concatenate()([resnet_pool, effnet_pool])

    # Custom classification head
    x = layers.Dense(1024, activation='relu')(merged)
    x = layers.Dropout(0.4)(x)

    # Output layer
    output_layer = layers.Dense(len(labels), activation='softmax')(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"hybrid_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr],
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.5991 - loss: 0.9910
# Epoch 1: val_accuracy improved from None to 0.75850, saving model to hybrid_fold_1.keras
#
# Epoch 1: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 117s 891ms/step - accuracy: 0.7101 - loss: 0.7329 - val_accuracy: 0.7585 - val_loss: 0.8040 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8457 - loss: 0.3839
# Epoch 2: val_accuracy improved from 0.75850 to 0.80272, saving model to hybrid_fold_1.keras
#
# Epoch 2: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 222ms/step - accuracy: 0.8531 - loss: 0.3788 - val_accuracy: 0.8027 - val_loss: 0.7684 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8983 - loss: 0.2701
# Epoch 3: val_accuracy improved from 0.80272 to 0.87585, saving model to hybrid_fold_1.keras
#
# Epoch 3: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - accuracy: 0.8991 - loss: 0.2751 - val_accuracy: 0.8759 - val_loss: 0.3958 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9266 - loss: 0.1940
# Epoch 4: val_accuracy did not improve from 0.87585
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.9225 - loss: 0.2083 - val_accuracy: 0.8588 - val_loss: 0.4348 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9325 - loss: 0.1813
# Epoch 5: val_accuracy improved from 0.87585 to 0.88095, saving model to hybrid_fold_1.keras
#
# Epoch 5: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9238 - loss: 0.1964 - val_accuracy: 0.8810 - val_loss: 0.3562 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9390 - loss: 0.1634
# Epoch 6: val_accuracy improved from 0.88095 to 0.89456, saving model to hybrid_fold_1.keras
#
# Epoch 6: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.9404 - loss: 0.1623 - val_accuracy: 0.8946 - val_loss: 0.3631 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9563 - loss: 0.1266
# Epoch 7: val_accuracy improved from 0.89456 to 0.89796, saving model to hybrid_fold_1.keras
#
# Epoch 7: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.9472 - loss: 0.1397 - val_accuracy: 0.8980 - val_loss: 0.4171 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9520 - loss: 0.1245
# Epoch 8: val_accuracy did not improve from 0.89796
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9506 - loss: 0.1234 - val_accuracy: 0.8810 - val_loss: 0.4157 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9493 - loss: 0.1230
# Epoch 9: val_accuracy did not improve from 0.89796
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9553 - loss: 0.1226 - val_accuracy: 0.8486 - val_loss: 0.5689 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9710 - loss: 0.0813
# Epoch 10: val_accuracy did not improve from 0.89796
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9693 - loss: 0.0830 - val_accuracy: 0.8929 - val_loss: 0.3896 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9787 - loss: 0.0627
# Epoch 11: val_accuracy improved from 0.89796 to 0.90306, saving model to hybrid_fold_1.keras
#
# Epoch 11: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 220ms/step - accuracy: 0.9800 - loss: 0.0627 - val_accuracy: 0.9031 - val_loss: 0.3566 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9845 - loss: 0.0545
# Epoch 12: val_accuracy improved from 0.90306 to 0.90986, saving model to hybrid_fold_1.keras
#
# Epoch 12: finished saving model to hybrid_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 229ms/step - accuracy: 0.9830 - loss: 0.0583 - val_accuracy: 0.9099 - val_loss: 0.3164 - learning_rate: 1.0000e-05
# Score for fold 1: loss of 0.3164; compile_metrics of 90.99%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.5989 - loss: 0.9791
# Epoch 1: val_accuracy improved from None to 0.79592, saving model to hybrid_fold_2.keras
#
# Epoch 1: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 91s 710ms/step - accuracy: 0.7143 - loss: 0.7273 - val_accuracy: 0.7959 - val_loss: 0.6046 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8524 - loss: 0.3797
# Epoch 2: val_accuracy improved from 0.79592 to 0.81803, saving model to hybrid_fold_2.keras
#
# Epoch 2: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.8702 - loss: 0.3585 - val_accuracy: 0.8180 - val_loss: 0.6382 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8891 - loss: 0.2737
# Epoch 3: val_accuracy improved from 0.81803 to 0.86565, saving model to hybrid_fold_2.keras
#
# Epoch 3: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.8889 - loss: 0.2846 - val_accuracy: 0.8656 - val_loss: 0.4114 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9128 - loss: 0.2148
# Epoch 4: val_accuracy improved from 0.86565 to 0.88265, saving model to hybrid_fold_2.keras
#
# Epoch 4: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.9123 - loss: 0.2298 - val_accuracy: 0.8827 - val_loss: 0.3772 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9359 - loss: 0.1941
# Epoch 5: val_accuracy did not improve from 0.88265
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9336 - loss: 0.2035 - val_accuracy: 0.8571 - val_loss: 0.4874 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9375 - loss: 0.1752
# Epoch 6: val_accuracy did not improve from 0.88265
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9315 - loss: 0.1854 - val_accuracy: 0.8724 - val_loss: 0.4308 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9573 - loss: 0.1208
# Epoch 7: val_accuracy improved from 0.88265 to 0.89626, saving model to hybrid_fold_2.keras
#
# Epoch 7: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 226ms/step - accuracy: 0.9634 - loss: 0.1147 - val_accuracy: 0.8963 - val_loss: 0.3347 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9596 - loss: 0.1050
# Epoch 8: val_accuracy improved from 0.89626 to 0.90136, saving model to hybrid_fold_2.keras
#
# Epoch 8: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.9621 - loss: 0.1042 - val_accuracy: 0.9014 - val_loss: 0.3128 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9644 - loss: 0.0973
# Epoch 9: val_accuracy improved from 0.90136 to 0.90306, saving model to hybrid_fold_2.keras
#
# Epoch 9: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 222ms/step - accuracy: 0.9617 - loss: 0.0991 - val_accuracy: 0.9031 - val_loss: 0.3126 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9646 - loss: 0.1071
# Epoch 10: val_accuracy did not improve from 0.90306
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.9659 - loss: 0.1013 - val_accuracy: 0.9014 - val_loss: 0.3286 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9673 - loss: 0.0957
# Epoch 11: val_accuracy improved from 0.90306 to 0.90646, saving model to hybrid_fold_2.keras
#
# Epoch 11: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 223ms/step - accuracy: 0.9706 - loss: 0.0950 - val_accuracy: 0.9065 - val_loss: 0.2967 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9742 - loss: 0.0794
# Epoch 12: val_accuracy improved from 0.90646 to 0.90816, saving model to hybrid_fold_2.keras
#
# Epoch 12: finished saving model to hybrid_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.9732 - loss: 0.0797 - val_accuracy: 0.9082 - val_loss: 0.2968 - learning_rate: 1.0000e-05
# Score for fold 2: loss of 0.2968; compile_metrics of 90.82%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - accuracy: 0.5715 - loss: 1.0163
# Epoch 1: val_accuracy improved from None to 0.79046, saving model to hybrid_fold_3.keras
#
# Epoch 1: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 107s 911ms/step - accuracy: 0.7145 - loss: 0.7062 - val_accuracy: 0.7905 - val_loss: 0.6771 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8700 - loss: 0.3481
# Epoch 2: val_accuracy improved from 0.79046 to 0.84668, saving model to hybrid_fold_3.keras
#
# Epoch 2: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 226ms/step - accuracy: 0.8753 - loss: 0.3413 - val_accuracy: 0.8467 - val_loss: 0.4734 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8875 - loss: 0.2867
# Epoch 3: val_accuracy improved from 0.84668 to 0.85349, saving model to hybrid_fold_3.keras
#
# Epoch 3: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.8953 - loss: 0.2790 - val_accuracy: 0.8535 - val_loss: 0.4601 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9182 - loss: 0.2414
# Epoch 4: val_accuracy improved from 0.85349 to 0.85520, saving model to hybrid_fold_3.keras
#
# Epoch 4: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - accuracy: 0.9162 - loss: 0.2464 - val_accuracy: 0.8552 - val_loss: 0.4717 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9382 - loss: 0.1730
# Epoch 5: val_accuracy improved from 0.85520 to 0.87564, saving model to hybrid_fold_3.keras
#
# Epoch 5: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - accuracy: 0.9353 - loss: 0.1805 - val_accuracy: 0.8756 - val_loss: 0.4570 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9408 - loss: 0.1539
# Epoch 6: val_accuracy did not improve from 0.87564
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9455 - loss: 0.1494 - val_accuracy: 0.8722 - val_loss: 0.4605 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9577 - loss: 0.1180
# Epoch 7: val_accuracy improved from 0.87564 to 0.89779, saving model to hybrid_fold_3.keras
#
# Epoch 7: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.9557 - loss: 0.1253 - val_accuracy: 0.8978 - val_loss: 0.3391 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9613 - loss: 0.1041
# Epoch 8: val_accuracy improved from 0.89779 to 0.90630, saving model to hybrid_fold_3.keras
#
# Epoch 8: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.9570 - loss: 0.1196 - val_accuracy: 0.9063 - val_loss: 0.3362 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9547 - loss: 0.1269
# Epoch 9: val_accuracy improved from 0.90630 to 0.91312, saving model to hybrid_fold_3.keras
#
# Epoch 9: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9583 - loss: 0.1173 - val_accuracy: 0.9131 - val_loss: 0.2940 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9709 - loss: 0.0848
# Epoch 10: val_accuracy did not improve from 0.91312
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.9677 - loss: 0.0931 - val_accuracy: 0.8978 - val_loss: 0.3636 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9652 - loss: 0.0844
# Epoch 11: val_accuracy improved from 0.91312 to 0.91823, saving model to hybrid_fold_3.keras
#
# Epoch 11: finished saving model to hybrid_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - accuracy: 0.9651 - loss: 0.0924 - val_accuracy: 0.9182 - val_loss: 0.3021 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9695 - loss: 0.0843
# Epoch 12: val_accuracy did not improve from 0.91823
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.9702 - loss: 0.0852 - val_accuracy: 0.9114 - val_loss: 0.3070 - learning_rate: 1.0000e-04
# Score for fold 3: loss of 0.3070; compile_metrics of 91.14%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5949 - loss: 0.9980
# Epoch 1: val_accuracy improved from None to 0.74957, saving model to hybrid_fold_4.keras
#
# Epoch 1: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 90s 700ms/step - accuracy: 0.7204 - loss: 0.7142 - val_accuracy: 0.7496 - val_loss: 0.7896 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8425 - loss: 0.3962
# Epoch 2: val_accuracy improved from 0.74957 to 0.77342, saving model to hybrid_fold_4.keras
#
# Epoch 2: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 243ms/step - accuracy: 0.8613 - loss: 0.3693 - val_accuracy: 0.7734 - val_loss: 0.7519 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8982 - loss: 0.3043
# Epoch 3: val_accuracy improved from 0.77342 to 0.87905, saving model to hybrid_fold_4.keras
#
# Epoch 3: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - accuracy: 0.9034 - loss: 0.2816 - val_accuracy: 0.8790 - val_loss: 0.4004 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9213 - loss: 0.2192
# Epoch 4: val_accuracy did not improve from 0.87905
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9157 - loss: 0.2133 - val_accuracy: 0.8654 - val_loss: 0.4972 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9237 - loss: 0.1893
# Epoch 5: val_accuracy did not improve from 0.87905
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.9289 - loss: 0.1844 - val_accuracy: 0.8654 - val_loss: 0.4589 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9604 - loss: 0.1268
# Epoch 6: val_accuracy improved from 0.87905 to 0.91823, saving model to hybrid_fold_4.keras
#
# Epoch 6: finished saving model to hybrid_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 222ms/step - accuracy: 0.9609 - loss: 0.1217 - val_accuracy: 0.9182 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9636 - loss: 0.1099
# Epoch 7: val_accuracy did not improve from 0.91823
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9540 - loss: 0.1228 - val_accuracy: 0.9148 - val_loss: 0.3541 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9562 - loss: 0.1174
# Epoch 8: val_accuracy did not improve from 0.91823
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9570 - loss: 0.1108 - val_accuracy: 0.9148 - val_loss: 0.3306 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9603 - loss: 0.1101
# Epoch 9: val_accuracy did not improve from 0.91823
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.9638 - loss: 0.1023 - val_accuracy: 0.9148 - val_loss: 0.3382 - learning_rate: 1.0000e-06
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9693 - loss: 0.0891
# Epoch 10: val_accuracy did not improve from 0.91823
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 196ms/step - accuracy: 0.9664 - loss: 0.0982 - val_accuracy: 0.9148 - val_loss: 0.3393 - learning_rate: 1.0000e-06
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9700 - loss: 0.0859
# Epoch 11: val_accuracy did not improve from 0.91823
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.9655 - loss: 0.0918 - val_accuracy: 0.9148 - val_loss: 0.3383 - learning_rate: 1.0000e-07
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9670 - loss: 0.0979
# Epoch 12: val_accuracy did not improve from 0.91823
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.9634 - loss: 0.0958 - val_accuracy: 0.9148 - val_loss: 0.3401 - learning_rate: 1.0000e-07
# Score for fold 4: loss of 0.3401; compile_metrics of 91.48%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.6270 - loss: 0.9068
# Epoch 1: val_accuracy improved from None to 0.79046, saving model to hybrid_fold_5.keras
#
# Epoch 1: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 90s 696ms/step - accuracy: 0.7174 - loss: 0.7183 - val_accuracy: 0.7905 - val_loss: 0.5158 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8653 - loss: 0.3832
# Epoch 2: val_accuracy did not improve from 0.79046
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 195ms/step - accuracy: 0.8655 - loss: 0.3680 - val_accuracy: 0.7785 - val_loss: 0.6644 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8927 - loss: 0.2837
# Epoch 3: val_accuracy improved from 0.79046 to 0.84838, saving model to hybrid_fold_5.keras
#
# Epoch 3: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 225ms/step - accuracy: 0.8936 - loss: 0.2812 - val_accuracy: 0.8484 - val_loss: 0.4298 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9170 - loss: 0.2219
# Epoch 4: val_accuracy improved from 0.84838 to 0.90630, saving model to hybrid_fold_5.keras
#
# Epoch 4: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 226ms/step - accuracy: 0.9098 - loss: 0.2436 - val_accuracy: 0.9063 - val_loss: 0.2704 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9381 - loss: 0.1693
# Epoch 5: val_accuracy did not improve from 0.90630
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.9345 - loss: 0.1790 - val_accuracy: 0.8910 - val_loss: 0.3524 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9489 - loss: 0.1472
# Epoch 6: val_accuracy did not improve from 0.90630
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 198ms/step - accuracy: 0.9379 - loss: 0.1735 - val_accuracy: 0.9046 - val_loss: 0.2652 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9489 - loss: 0.1346
# Epoch 7: val_accuracy improved from 0.90630 to 0.91652, saving model to hybrid_fold_5.keras
#
# Epoch 7: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - accuracy: 0.9604 - loss: 0.1163 - val_accuracy: 0.9165 - val_loss: 0.2177 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9729 - loss: 0.0962
# Epoch 8: val_accuracy improved from 0.91652 to 0.92164, saving model to hybrid_fold_5.keras
#
# Epoch 8: finished saving model to hybrid_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - accuracy: 0.9685 - loss: 0.0985 - val_accuracy: 0.9216 - val_loss: 0.2132 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9679 - loss: 0.0926
# Epoch 9: val_accuracy did not improve from 0.92164
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.9689 - loss: 0.0942 - val_accuracy: 0.9131 - val_loss: 0.2058 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9672 - loss: 0.0872
# Epoch 10: val_accuracy did not improve from 0.92164
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.9694 - loss: 0.0847 - val_accuracy: 0.9080 - val_loss: 0.2325 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9805 - loss: 0.0775
# Epoch 11: val_accuracy did not improve from 0.92164
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9728 - loss: 0.0853 - val_accuracy: 0.9080 - val_loss: 0.2242 - learning_rate: 1.0000e-06
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9817 - loss: 0.0698
# Epoch 12: val_accuracy did not improve from 0.92164
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.9740 - loss: 0.0831 - val_accuracy: 0.9080 - val_loss: 0.2186 - learning_rate: 1.0000e-06
# Score for fold 5: loss of 0.2186; compile_metrics of 90.80%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.3164 - Accuracy: 90.99%
# > Fold 2 - Loss: 0.2968 - Accuracy: 90.82%
# > Fold 3 - Loss: 0.3070 - Accuracy: 91.14%
# > Fold 4 - Loss: 0.3401 - Accuracy: 91.48%
# > Fold 5 - Loss: 0.2186 - Accuracy: 90.80%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 91.05% (+- 0.25%)
# > Loss: 0.2958
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
# model = tf.keras.models.load_model('hybrid_fold_2.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.94      0.95      0.94        93
#         no_tumor       0.96      0.98      0.97        51
# meningioma_tumor       0.94      0.79      0.86        96
#  pituitary_tumor       0.86      0.99      0.92        87
#
#         accuracy                           0.92       327
#        macro avg       0.92      0.93      0.92       327
#     weighted avg       0.92      0.92      0.92       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Save the final trained model
model_cv.save('/content/gdrive/MyDrive/brain_tumor/models/efficientnetb0_resnet50_model(2).keras.keras')

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(10).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
