# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:16<00:00, 50.14it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:04<00:00, 81.90it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:16<00:00, 49.18it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:17<00:00, 47.14it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:01<00:00, 63.64it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:01<00:00, 73.50it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:01<00:00, 65.38it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:18<00:00,  4.09it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: VGG16

# %%
from sklearn.model_selection import KFold
import tensorflow as tf

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    base_model = tf.keras.applications.VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
    )

    # Freeze most layers (transfer learning)
    for layer in base_model.layers[:-4]:   # fine-tune last 4 layers only
        layer.trainable = False

    for layer in base_model.layers[-4:]:
        layer.trainable = True

    x = base_model.output

    # Better head
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    outputs = tf.keras.layers.Dense(4, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=base_model.input, outputs=outputs)

    # Compile with better optimizer settings
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"vgg16_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr]
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.4232 - loss: 1.5509
# Epoch 1: val_accuracy improved from None to 0.70578, saving model to vgg16_fold_1.keras
#
# Epoch 1: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.5011 - loss: 1.2761 - val_accuracy: 0.7058 - val_loss: 0.9927 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6709 - loss: 0.8362
# Epoch 2: val_accuracy improved from 0.70578 to 0.79932, saving model to vgg16_fold_1.keras
#
# Epoch 2: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.7003 - loss: 0.7673 - val_accuracy: 0.7993 - val_loss: 0.6265 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7580 - loss: 0.6558
# Epoch 3: val_accuracy improved from 0.79932 to 0.84014, saving model to vgg16_fold_1.keras
#
# Epoch 3: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 218ms/step - accuracy: 0.7701 - loss: 0.6087 - val_accuracy: 0.8401 - val_loss: 0.4308 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8072 - loss: 0.5223
# Epoch 4: val_accuracy improved from 0.84014 to 0.86565, saving model to vgg16_fold_1.keras
#
# Epoch 4: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.8199 - loss: 0.4850 - val_accuracy: 0.8656 - val_loss: 0.3871 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8197 - loss: 0.4841
# Epoch 5: val_accuracy did not improve from 0.86565
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.8293 - loss: 0.4505 - val_accuracy: 0.8486 - val_loss: 0.5142 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8533 - loss: 0.4110
# Epoch 6: val_accuracy did not improve from 0.86565
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.8629 - loss: 0.3906 - val_accuracy: 0.7143 - val_loss: 1.2528 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8770 - loss: 0.3596
# Epoch 7: val_accuracy improved from 0.86565 to 0.88435, saving model to vgg16_fold_1.keras
#
# Epoch 7: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.8821 - loss: 0.3429 - val_accuracy: 0.8844 - val_loss: 0.3863 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8794 - loss: 0.3309
# Epoch 8: val_accuracy improved from 0.88435 to 0.88776, saving model to vgg16_fold_1.keras
#
# Epoch 8: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 220ms/step - accuracy: 0.8893 - loss: 0.3141 - val_accuracy: 0.8878 - val_loss: 0.3132 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8822 - loss: 0.3240
# Epoch 9: val_accuracy improved from 0.88776 to 0.89286, saving model to vgg16_fold_1.keras
#
# Epoch 9: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.8893 - loss: 0.3126 - val_accuracy: 0.8929 - val_loss: 0.3213 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8996 - loss: 0.2870
# Epoch 10: val_accuracy improved from 0.89286 to 0.89966, saving model to vgg16_fold_1.keras
#
# Epoch 10: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.8995 - loss: 0.2954 - val_accuracy: 0.8997 - val_loss: 0.3168 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9005 - loss: 0.2815
# Epoch 11: val_accuracy improved from 0.89966 to 0.90136, saving model to vgg16_fold_1.keras
#
# Epoch 11: finished saving model to vgg16_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 218ms/step - accuracy: 0.9000 - loss: 0.2805 - val_accuracy: 0.9014 - val_loss: 0.3440 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9088 - loss: 0.2846
# Epoch 12: val_accuracy did not improve from 0.90136
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9085 - loss: 0.2777 - val_accuracy: 0.8963 - val_loss: 0.3091 - learning_rate: 1.0000e-05
# Score for fold 1: loss of 0.3091; compile_metrics of 89.63%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.3757 - loss: 1.5093
# Epoch 1: val_accuracy improved from None to 0.56973, saving model to vgg16_fold_2.keras
#
# Epoch 1: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 25s 271ms/step - accuracy: 0.4708 - loss: 1.2987 - val_accuracy: 0.5697 - val_loss: 1.3039 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6588 - loss: 0.9100
# Epoch 2: val_accuracy improved from 0.56973 to 0.80952, saving model to vgg16_fold_2.keras
#
# Epoch 2: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.6769 - loss: 0.8483 - val_accuracy: 0.8095 - val_loss: 0.5911 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7488 - loss: 0.6635
# Epoch 3: val_accuracy improved from 0.80952 to 0.85544, saving model to vgg16_fold_2.keras
#
# Epoch 3: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.7612 - loss: 0.6288 - val_accuracy: 0.8554 - val_loss: 0.4529 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7983 - loss: 0.5528
# Epoch 4: val_accuracy improved from 0.85544 to 0.86054, saving model to vgg16_fold_2.keras
#
# Epoch 4: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 226ms/step - accuracy: 0.7986 - loss: 0.5547 - val_accuracy: 0.8605 - val_loss: 0.4594 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8148 - loss: 0.5037
# Epoch 5: val_accuracy improved from 0.86054 to 0.86395, saving model to vgg16_fold_2.keras
#
# Epoch 5: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 220ms/step - accuracy: 0.8267 - loss: 0.4735 - val_accuracy: 0.8639 - val_loss: 0.4066 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8512 - loss: 0.4328
# Epoch 6: val_accuracy did not improve from 0.86395
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.8484 - loss: 0.4153 - val_accuracy: 0.8639 - val_loss: 0.4635 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8717 - loss: 0.3908
# Epoch 7: val_accuracy improved from 0.86395 to 0.89796, saving model to vgg16_fold_2.keras
#
# Epoch 7: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 218ms/step - accuracy: 0.8744 - loss: 0.3740 - val_accuracy: 0.8980 - val_loss: 0.3088 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8900 - loss: 0.3107
# Epoch 8: val_accuracy did not improve from 0.89796
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8889 - loss: 0.3194 - val_accuracy: 0.8673 - val_loss: 0.3839 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8852 - loss: 0.2891
# Epoch 9: val_accuracy improved from 0.89796 to 0.90986, saving model to vgg16_fold_2.keras
#
# Epoch 9: finished saving model to vgg16_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.8957 - loss: 0.2836 - val_accuracy: 0.9099 - val_loss: 0.3010 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9075 - loss: 0.2663
# Epoch 10: val_accuracy did not improve from 0.90986
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.9089 - loss: 0.2806 - val_accuracy: 0.8878 - val_loss: 0.3478 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9353 - loss: 0.2100
# Epoch 11: val_accuracy did not improve from 0.90986
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.9187 - loss: 0.2432 - val_accuracy: 0.9031 - val_loss: 0.3247 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9193 - loss: 0.2137
# Epoch 12: val_accuracy did not improve from 0.90986
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.9217 - loss: 0.2114 - val_accuracy: 0.9048 - val_loss: 0.2827 - learning_rate: 1.0000e-05
# Score for fold 2: loss of 0.2827; compile_metrics of 90.48%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.4121 - loss: 1.5310
# Epoch 1: val_accuracy improved from None to 0.73765, saving model to vgg16_fold_3.keras
#
# Epoch 1: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 33s 381ms/step - accuracy: 0.5213 - loss: 1.2174 - val_accuracy: 0.7376 - val_loss: 0.7418 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7032 - loss: 0.7859
# Epoch 2: val_accuracy improved from 0.73765 to 0.78705, saving model to vgg16_fold_3.keras
#
# Epoch 2: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.7366 - loss: 0.6980 - val_accuracy: 0.7871 - val_loss: 0.6980 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7894 - loss: 0.5504
# Epoch 3: val_accuracy improved from 0.78705 to 0.82283, saving model to vgg16_fold_3.keras
#
# Epoch 3: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.7932 - loss: 0.5617 - val_accuracy: 0.8228 - val_loss: 0.5412 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8148 - loss: 0.5127
# Epoch 4: val_accuracy improved from 0.82283 to 0.84157, saving model to vgg16_fold_3.keras
#
# Epoch 4: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 217ms/step - accuracy: 0.8230 - loss: 0.4689 - val_accuracy: 0.8416 - val_loss: 0.4760 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8548 - loss: 0.4032
# Epoch 5: val_accuracy did not improve from 0.84157
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.8604 - loss: 0.3960 - val_accuracy: 0.7683 - val_loss: 0.8460 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8751 - loss: 0.3581
# Epoch 6: val_accuracy did not improve from 0.84157
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.8715 - loss: 0.3794 - val_accuracy: 0.7888 - val_loss: 0.6730 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8682 - loss: 0.3572
# Epoch 7: val_accuracy improved from 0.84157 to 0.85520, saving model to vgg16_fold_3.keras
#
# Epoch 7: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.8872 - loss: 0.3226 - val_accuracy: 0.8552 - val_loss: 0.4299 - learning_rate: 1.0000e-05
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9021 - loss: 0.2840
# Epoch 8: val_accuracy improved from 0.85520 to 0.86712, saving model to vgg16_fold_3.keras
#
# Epoch 8: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 221ms/step - accuracy: 0.8949 - loss: 0.3046 - val_accuracy: 0.8671 - val_loss: 0.3756 - learning_rate: 1.0000e-05
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9017 - loss: 0.2706
# Epoch 9: val_accuracy improved from 0.86712 to 0.88245, saving model to vgg16_fold_3.keras
#
# Epoch 9: finished saving model to vgg16_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - accuracy: 0.9043 - loss: 0.2708 - val_accuracy: 0.8825 - val_loss: 0.3516 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9117 - loss: 0.2530
# Epoch 10: val_accuracy did not improve from 0.88245
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.9038 - loss: 0.2669 - val_accuracy: 0.8825 - val_loss: 0.3317 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9003 - loss: 0.2972
# Epoch 11: val_accuracy did not improve from 0.88245
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 220ms/step - accuracy: 0.9106 - loss: 0.2647 - val_accuracy: 0.8807 - val_loss: 0.3657 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9100 - loss: 0.2518
# Epoch 12: val_accuracy did not improve from 0.88245
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.9094 - loss: 0.2540 - val_accuracy: 0.8773 - val_loss: 0.3637 - learning_rate: 1.0000e-06
# Score for fold 3: loss of 0.3637; compile_metrics of 87.73%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.4169 - loss: 1.5652
# Epoch 1: val_accuracy improved from None to 0.65247, saving model to vgg16_fold_4.keras
#
# Epoch 1: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 26s 283ms/step - accuracy: 0.5077 - loss: 1.2693 - val_accuracy: 0.6525 - val_loss: 1.1355 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6680 - loss: 0.8152
# Epoch 2: val_accuracy improved from 0.65247 to 0.78194, saving model to vgg16_fold_4.keras
#
# Epoch 2: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 235ms/step - accuracy: 0.6966 - loss: 0.7744 - val_accuracy: 0.7819 - val_loss: 0.6149 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7850 - loss: 0.5866
# Epoch 3: val_accuracy improved from 0.78194 to 0.79727, saving model to vgg16_fold_4.keras
#
# Epoch 3: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 242ms/step - accuracy: 0.7885 - loss: 0.5798 - val_accuracy: 0.7973 - val_loss: 0.6031 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8189 - loss: 0.4929
# Epoch 4: val_accuracy did not improve from 0.79727
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 232ms/step - accuracy: 0.8145 - loss: 0.5112 - val_accuracy: 0.7581 - val_loss: 0.6655 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8465 - loss: 0.4306
# Epoch 5: val_accuracy improved from 0.79727 to 0.83646, saving model to vgg16_fold_4.keras
#
# Epoch 5: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 234ms/step - accuracy: 0.8460 - loss: 0.4237 - val_accuracy: 0.8365 - val_loss: 0.4820 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8664 - loss: 0.3829
# Epoch 6: val_accuracy improved from 0.83646 to 0.87394, saving model to vgg16_fold_4.keras
#
# Epoch 6: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.8579 - loss: 0.3972 - val_accuracy: 0.8739 - val_loss: 0.4001 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8702 - loss: 0.3694
# Epoch 7: val_accuracy did not improve from 0.87394
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.8770 - loss: 0.3574 - val_accuracy: 0.8484 - val_loss: 0.5399 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9011 - loss: 0.2979
# Epoch 8: val_accuracy did not improve from 0.87394
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 223ms/step - accuracy: 0.9000 - loss: 0.2931 - val_accuracy: 0.8671 - val_loss: 0.3865 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9072 - loss: 0.2869
# Epoch 9: val_accuracy did not improve from 0.87394
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 217ms/step - accuracy: 0.9102 - loss: 0.2648 - val_accuracy: 0.8705 - val_loss: 0.4063 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9052 - loss: 0.2619
# Epoch 10: val_accuracy did not improve from 0.87394
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - accuracy: 0.9115 - loss: 0.2466 - val_accuracy: 0.8688 - val_loss: 0.4307 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9126 - loss: 0.2454
# Epoch 11: val_accuracy improved from 0.87394 to 0.87905, saving model to vgg16_fold_4.keras
#
# Epoch 11: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - accuracy: 0.9157 - loss: 0.2399 - val_accuracy: 0.8790 - val_loss: 0.3803 - learning_rate: 1.0000e-06
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9172 - loss: 0.2401
# Epoch 12: val_accuracy improved from 0.87905 to 0.89267, saving model to vgg16_fold_4.keras
#
# Epoch 12: finished saving model to vgg16_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 226ms/step - accuracy: 0.9174 - loss: 0.2417 - val_accuracy: 0.8927 - val_loss: 0.3448 - learning_rate: 1.0000e-06
# Score for fold 4: loss of 0.3448; compile_metrics of 89.27%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.4281 - loss: 1.5500
# Epoch 1: val_accuracy improved from None to 0.68143, saving model to vgg16_fold_5.keras
#
# Epoch 1: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 26s 286ms/step - accuracy: 0.5285 - loss: 1.2636 - val_accuracy: 0.6814 - val_loss: 0.9611 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7077 - loss: 0.7866
# Epoch 2: val_accuracy improved from 0.68143 to 0.77853, saving model to vgg16_fold_5.keras
#
# Epoch 2: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.7238 - loss: 0.7535 - val_accuracy: 0.7785 - val_loss: 0.6806 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7476 - loss: 0.6706
# Epoch 3: val_accuracy improved from 0.77853 to 0.78705, saving model to vgg16_fold_5.keras
#
# Epoch 3: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - accuracy: 0.7762 - loss: 0.5971 - val_accuracy: 0.7871 - val_loss: 0.6719 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8329 - loss: 0.4820
# Epoch 4: val_accuracy improved from 0.78705 to 0.83135, saving model to vgg16_fold_5.keras
#
# Epoch 4: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.8243 - loss: 0.4920 - val_accuracy: 0.8313 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8459 - loss: 0.4185
# Epoch 5: val_accuracy improved from 0.83135 to 0.86031, saving model to vgg16_fold_5.keras
#
# Epoch 5: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.8481 - loss: 0.4153 - val_accuracy: 0.8603 - val_loss: 0.3705 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8654 - loss: 0.3694
# Epoch 6: val_accuracy improved from 0.86031 to 0.89608, saving model to vgg16_fold_5.keras
#
# Epoch 6: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.8587 - loss: 0.3880 - val_accuracy: 0.8961 - val_loss: 0.3221 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8803 - loss: 0.3426
# Epoch 7: val_accuracy did not improve from 0.89608
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.8847 - loss: 0.3289 - val_accuracy: 0.8569 - val_loss: 0.4537 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9002 - loss: 0.2710
# Epoch 8: val_accuracy did not improve from 0.89608
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.9038 - loss: 0.2776 - val_accuracy: 0.8944 - val_loss: 0.3268 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9151 - loss: 0.2465
# Epoch 9: val_accuracy improved from 0.89608 to 0.90119, saving model to vgg16_fold_5.keras
#
# Epoch 9: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.9132 - loss: 0.2363 - val_accuracy: 0.9012 - val_loss: 0.3118 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9267 - loss: 0.2082
# Epoch 10: val_accuracy improved from 0.90119 to 0.90971, saving model to vgg16_fold_5.keras
#
# Epoch 10: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 222ms/step - accuracy: 0.9234 - loss: 0.2240 - val_accuracy: 0.9097 - val_loss: 0.2966 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9255 - loss: 0.1925
# Epoch 11: val_accuracy improved from 0.90971 to 0.91823, saving model to vgg16_fold_5.keras
#
# Epoch 11: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.9255 - loss: 0.2047 - val_accuracy: 0.9182 - val_loss: 0.2582 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9376 - loss: 0.1861
# Epoch 12: val_accuracy improved from 0.91823 to 0.92334, saving model to vgg16_fold_5.keras
#
# Epoch 12: finished saving model to vgg16_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 223ms/step - accuracy: 0.9302 - loss: 0.2091 - val_accuracy: 0.9233 - val_loss: 0.2479 - learning_rate: 1.0000e-05
# Score for fold 5: loss of 0.2479; compile_metrics of 92.33%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.3091 - Accuracy: 89.63%
# > Fold 2 - Loss: 0.2827 - Accuracy: 90.48%
# > Fold 3 - Loss: 0.3637 - Accuracy: 87.73%
# > Fold 4 - Loss: 0.3448 - Accuracy: 89.27%
# > Fold 5 - Loss: 0.2479 - Accuracy: 92.33%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 89.89% (+- 1.51%)
# > Loss: 0.3096
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
# model = tf.keras.models.load_model('efficientnetB0_fold_5.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model_cv.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.88      0.99      0.93        93
#         no_tumor       0.92      0.94      0.93        51
# meningioma_tumor       0.95      0.72      0.82        96
#  pituitary_tumor       0.88      0.98      0.92        87
#
#         accuracy                           0.90       327
#        macro avg       0.91      0.91      0.90       327
#     weighted avg       0.90      0.90      0.90       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model_cv)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
