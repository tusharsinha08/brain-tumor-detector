# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import Libraries

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Load Dataset for Preprocessing

# %%
TRAIN_PATH = '/content/gdrive/MyDrive/dataset/Training'
TEST_PATH = '/content/gdrive/MyDrive/dataset/Testing'

IMAGE_SIZE = 150

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Initialize lists to store images and labels
X_train = []
y_train = []

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

print(f"Preprocessing training data from: {TRAIN_PATH}")
for i in labels:
    folderPath = os.path.join(TRAIN_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Training subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} training images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

print(f"\nPreprocessing testing data from: {TEST_PATH}")
for i in labels:
    folderPath = os.path.join(TEST_PATH, i)
    if not os.path.exists(folderPath):
        print(f"Warning: Testing subfolder {folderPath} does not exist. Skipping.")
        continue
    for j in tqdm(os.listdir(folderPath), desc=f"Loading {i} testing images"):
        img = cv2.imread(os.path.join(folderPath, j))
        if img is None:
            print(f"Warning: Could not read image {os.path.join(folderPath, j)}. Skipping.")
            continue
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
        X_train.append(img)
        y_train.append(i)

# Convert lists to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

print(f"\nFinished preprocessing. X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Preprocessing training data from: /content/gdrive/MyDrive/dataset/Training
# Loading glioma_tumor training images: 100%|██████████| 826/826 [00:17<00:00, 47.35it/s]
# Loading no_tumor training images: 100%|██████████| 395/395 [00:04<00:00, 79.74it/s]
# Loading meningioma_tumor training images: 100%|██████████| 822/822 [00:11<00:00, 70.93it/s]
# Loading pituitary_tumor training images: 100%|██████████| 827/827 [00:17<00:00, 46.24it/s]
# Preprocessing testing data from: /content/gdrive/MyDrive/dataset/Testing
# Loading glioma_tumor testing images: 100%|██████████| 100/100 [00:01<00:00, 60.04it/s]
# Loading no_tumor testing images: 100%|██████████| 105/105 [00:01<00:00, 56.20it/s]
# Loading meningioma_tumor testing images: 100%|██████████| 115/115 [00:03<00:00, 32.21it/s]
# Loading pituitary_tumor testing images: 100%|██████████| 74/74 [00:21<00:00,  3.51it/s]
# Finished preprocessing. X_train shape: (3264, 150, 150, 3), y_train shape: (3264,)

# %% [markdown]
# Data visualization

# %%
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(12, 10)) # Increased figure size for better visualization

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"] # Using default matplotlib colors or similar

# Plot the histogram
plt.subplot(2, 1, 1)
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
# mplcyberpunk.add_bar_gradient(bars=bars) # Removed mplcyberpunk dependency
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        # Ensure index j is within bounds of X_train and y_train
        if j < len(y_train) and y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1
        # Add a safeguard to prevent infinite loops if a label has no images
        if j >= len(y_train):
            print(f"Warning: No images found for label: {i}")
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dataset Split: Train and Test

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# ### One-Hot Encoding Labels

# %%
import numpy as np
import tensorflow as tf

# Safely encode labels to categorical only if they are not already one-hot encoded
if len(np.array(y_train).shape) == 1:
    y_train_new = [labels.index(i) for i in y_train]
    y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))

if len(np.array(y_test).shape) == 1:
    y_test_new = [labels.index(i) for i in y_test]
    y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# y_train shape: (2937, 4)
# y_test shape: (327, 4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Split validation data manually since model.fit's validation_split doesn't work directly with data generators
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# Create the ImageDataGenerator with augmentations
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Prepare the generator
datagen.fit(X_train_split)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Get a batch of augmented images from the generator
aug_iter = datagen.flow(X_train_split, y_train_split, batch_size=9)
aug_images, aug_labels = next(aug_iter)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)

    # The generator outputs float32, we convert to uint8 for visualization
    img = aug_images[i].astype(np.uint8)

    # Convert BGR (from cv2) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)

    # Get the label string from the one-hot encoded label
    label_index = np.argmax(aug_labels[i])
    plt.title(f"Augmented: {labels[label_index]}")
    plt.axis('off')

plt.suptitle("Sample Augmented Images", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Model: InceptionV3 (GoogleNet)

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Define K-Fold Cross Validation before building models
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=101)

def build_model():
    base_model = tf.keras.applications.InceptionV3(
        weights='imagenet',
        include_top=False,
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
    )


    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(len(labels), activation='softmax')(x)

    model = models.Model(inputs=base_model.input, outputs=output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

print(f"{k_folds}-Fold Validation setup complete.")
# Out:
# 5-Fold Validation setup complete.

# %%
import numpy as np
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

# Arrays to store scores
acc_per_fold = []
loss_per_fold = []

fold_no = 1

# Convert y_train back to categorical labels for splitting if it's one-hot encoded
y_train_labels = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train

print(f"Starting {k_folds}-fold cross validation...")

for train_index, val_index in kfold.split(X_train, y_train_labels):
    print(f'\nTraining for fold {fold_no} ...')

    # Split data for this fold
    X_fold_train, X_fold_val = X_train[train_index], X_train[val_index]
    y_fold_train, y_fold_val = y_train[train_index], y_train[val_index]

    # Generate a fresh model
    model_cv = build_model()

    # Define callbacks for this specific fold
    tensorboard = TensorBoard(log_dir=f'logs/fold_{fold_no}')
    checkpoint = ModelCheckpoint(f"inceptionV3_fold_{fold_no}.keras", monitor="val_accuracy",
                                 save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2,
                                  min_delta=0.0001, verbose=1)

    # Train the model
    history = model_cv.fit(
        datagen.flow(X_fold_train, y_fold_train, batch_size=32),
        validation_data=(X_fold_val, y_fold_val),
        epochs=12,
        verbose=1,
        callbacks=[tensorboard, checkpoint, reduce_lr],
    )

    # Evaluate the model on the validation set for this fold
    scores = model_cv.evaluate(X_fold_val, y_fold_val, verbose=0)
    print(f'Score for fold {fold_no}: {model_cv.metrics_names[0]} of {scores[0]:.4f}; {model_cv.metrics_names[1]} of {scores[1]*100:.2f}%')

    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    fold_no += 1

print('\n------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:.4f} - Accuracy: {acc_per_fold[i]:.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (+- {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f}')
print('------------------------------------------------------------------------')
# Out:
# Starting 5-fold cross validation...
#
# Training for fold 1 ...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.5024 - loss: 1.3980
# Epoch 1: val_accuracy improved from None to 0.61565, saving model to inceptionV3_fold_1.keras
#
# Epoch 1: finished saving model to inceptionV3_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 134s 853ms/step - accuracy: 0.6117 - loss: 1.1119 - val_accuracy: 0.6156 - val_loss: 1.1675 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7788 - loss: 0.6644
# Epoch 2: val_accuracy improved from 0.61565 to 0.81293, saving model to inceptionV3_fold_1.keras
#
# Epoch 2: finished saving model to inceptionV3_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.7948 - loss: 0.6166 - val_accuracy: 0.8129 - val_loss: 0.5031 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8336 - loss: 0.4926
# Epoch 3: val_accuracy improved from 0.81293 to 0.85714, saving model to inceptionV3_fold_1.keras
#
# Epoch 3: finished saving model to inceptionV3_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.8348 - loss: 0.4862 - val_accuracy: 0.8571 - val_loss: 0.4270 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8741 - loss: 0.3582
# Epoch 4: val_accuracy did not improve from 0.85714
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.8629 - loss: 0.3838 - val_accuracy: 0.8503 - val_loss: 0.4869 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8904 - loss: 0.3150
# Epoch 5: val_accuracy improved from 0.85714 to 0.89286, saving model to inceptionV3_fold_1.keras
#
# Epoch 5: finished saving model to inceptionV3_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.8948 - loss: 0.3098 - val_accuracy: 0.8929 - val_loss: 0.3188 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9097 - loss: 0.2823
# Epoch 6: val_accuracy improved from 0.89286 to 0.92007, saving model to inceptionV3_fold_1.keras
#
# Epoch 6: finished saving model to inceptionV3_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.9068 - loss: 0.2855 - val_accuracy: 0.9201 - val_loss: 0.2583 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9250 - loss: 0.2175
# Epoch 7: val_accuracy improved from 0.92007 to 0.92347, saving model to inceptionV3_fold_1.keras
#
# Epoch 7: finished saving model to inceptionV3_fold_1.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9208 - loss: 0.2220 - val_accuracy: 0.9235 - val_loss: 0.2208 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9415 - loss: 0.1639
# Epoch 8: val_accuracy did not improve from 0.92347
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.9336 - loss: 0.1893 - val_accuracy: 0.9235 - val_loss: 0.2126 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9512 - loss: 0.1499
# Epoch 9: val_accuracy did not improve from 0.92347
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.9421 - loss: 0.1685 - val_accuracy: 0.9218 - val_loss: 0.2443 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9448 - loss: 0.1514
# Epoch 10: val_accuracy did not improve from 0.92347
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.9464 - loss: 0.1475 - val_accuracy: 0.9184 - val_loss: 0.2315 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9568 - loss: 0.1258
# Epoch 11: val_accuracy did not improve from 0.92347
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.9613 - loss: 0.1193 - val_accuracy: 0.9184 - val_loss: 0.2277 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9599 - loss: 0.1155
# Epoch 12: val_accuracy did not improve from 0.92347
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9591 - loss: 0.1139 - val_accuracy: 0.9235 - val_loss: 0.2302 - learning_rate: 1.0000e-06
# Score for fold 1: loss of 0.2302; compile_metrics of 92.35%
#
# Training for fold 2 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.4752 - loss: 1.4200
# Epoch 1: val_accuracy improved from None to 0.53571, saving model to inceptionV3_fold_2.keras
#
# Epoch 1: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 116s 753ms/step - accuracy: 0.5858 - loss: 1.1408 - val_accuracy: 0.5357 - val_loss: 1.3223 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7891 - loss: 0.6155
# Epoch 2: val_accuracy improved from 0.53571 to 0.79762, saving model to inceptionV3_fold_2.keras
#
# Epoch 2: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.7991 - loss: 0.5853 - val_accuracy: 0.7976 - val_loss: 0.5150 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8359 - loss: 0.4707
# Epoch 3: val_accuracy improved from 0.79762 to 0.83503, saving model to inceptionV3_fold_2.keras
#
# Epoch 3: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8378 - loss: 0.4910 - val_accuracy: 0.8350 - val_loss: 0.4291 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8648 - loss: 0.3853
# Epoch 4: val_accuracy improved from 0.83503 to 0.84524, saving model to inceptionV3_fold_2.keras
#
# Epoch 4: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.8625 - loss: 0.3862 - val_accuracy: 0.8452 - val_loss: 0.4246 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8901 - loss: 0.3157
# Epoch 5: val_accuracy improved from 0.84524 to 0.88946, saving model to inceptionV3_fold_2.keras
#
# Epoch 5: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8927 - loss: 0.3112 - val_accuracy: 0.8895 - val_loss: 0.4161 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8943 - loss: 0.2872
# Epoch 6: val_accuracy improved from 0.88946 to 0.90136, saving model to inceptionV3_fold_2.keras
#
# Epoch 6: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9004 - loss: 0.2754 - val_accuracy: 0.9014 - val_loss: 0.3150 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9299 - loss: 0.1828
# Epoch 7: val_accuracy improved from 0.90136 to 0.90476, saving model to inceptionV3_fold_2.keras
#
# Epoch 7: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9246 - loss: 0.2036 - val_accuracy: 0.9048 - val_loss: 0.3388 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9362 - loss: 0.1795
# Epoch 8: val_accuracy improved from 0.90476 to 0.93537, saving model to inceptionV3_fold_2.keras
#
# Epoch 8: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9370 - loss: 0.1836 - val_accuracy: 0.9354 - val_loss: 0.2284 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9355 - loss: 0.1753
# Epoch 9: val_accuracy did not improve from 0.93537
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9391 - loss: 0.1750 - val_accuracy: 0.9133 - val_loss: 0.3032 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9452 - loss: 0.1580
# Epoch 10: val_accuracy improved from 0.93537 to 0.93707, saving model to inceptionV3_fold_2.keras
#
# Epoch 10: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.9391 - loss: 0.1771 - val_accuracy: 0.9371 - val_loss: 0.2486 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9585 - loss: 0.1232
# Epoch 11: val_accuracy improved from 0.93707 to 0.94728, saving model to inceptionV3_fold_2.keras
#
# Epoch 11: finished saving model to inceptionV3_fold_2.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - accuracy: 0.9570 - loss: 0.1284 - val_accuracy: 0.9473 - val_loss: 0.1972 - learning_rate: 1.0000e-04
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9642 - loss: 0.1056
# Epoch 12: val_accuracy did not improve from 0.94728
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.9621 - loss: 0.1162 - val_accuracy: 0.9371 - val_loss: 0.3112 - learning_rate: 1.0000e-04
# Score for fold 2: loss of 0.3112; compile_metrics of 93.71%
#
# Training for fold 3 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.4886 - loss: 1.3581
# Epoch 1: val_accuracy improved from None to 0.57922, saving model to inceptionV3_fold_3.keras
#
# Epoch 1: finished saving model to inceptionV3_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 123s 841ms/step - accuracy: 0.6243 - loss: 1.0507 - val_accuracy: 0.5792 - val_loss: 1.1032 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7652 - loss: 0.6907
# Epoch 2: val_accuracy improved from 0.57922 to 0.81261, saving model to inceptionV3_fold_3.keras
#
# Epoch 2: finished saving model to inceptionV3_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.7826 - loss: 0.6542 - val_accuracy: 0.8126 - val_loss: 0.5453 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8333 - loss: 0.4763
# Epoch 3: val_accuracy improved from 0.81261 to 0.88416, saving model to inceptionV3_fold_3.keras
#
# Epoch 3: finished saving model to inceptionV3_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.8468 - loss: 0.4509 - val_accuracy: 0.8842 - val_loss: 0.3550 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8843 - loss: 0.3132
# Epoch 4: val_accuracy did not improve from 0.88416
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.8817 - loss: 0.3209 - val_accuracy: 0.8756 - val_loss: 0.3706 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9078 - loss: 0.2864
# Epoch 5: val_accuracy improved from 0.88416 to 0.90290, saving model to inceptionV3_fold_3.keras
#
# Epoch 5: finished saving model to inceptionV3_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9089 - loss: 0.2711 - val_accuracy: 0.9029 - val_loss: 0.2539 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9239 - loss: 0.2190
# Epoch 6: val_accuracy improved from 0.90290 to 0.92164, saving model to inceptionV3_fold_3.keras
#
# Epoch 6: finished saving model to inceptionV3_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - accuracy: 0.9196 - loss: 0.2218 - val_accuracy: 0.9216 - val_loss: 0.2224 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9441 - loss: 0.1787
# Epoch 7: val_accuracy did not improve from 0.92164
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9387 - loss: 0.1877 - val_accuracy: 0.9199 - val_loss: 0.2142 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9514 - loss: 0.1334
# Epoch 8: val_accuracy did not improve from 0.92164
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 178ms/step - accuracy: 0.9485 - loss: 0.1416 - val_accuracy: 0.9114 - val_loss: 0.3068 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9460 - loss: 0.1478
# Epoch 9: val_accuracy did not improve from 0.92164
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 177ms/step - accuracy: 0.9468 - loss: 0.1467 - val_accuracy: 0.9216 - val_loss: 0.2474 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9398 - loss: 0.1569
# Epoch 10: val_accuracy improved from 0.92164 to 0.92845, saving model to inceptionV3_fold_3.keras
#
# Epoch 10: finished saving model to inceptionV3_fold_3.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.9481 - loss: 0.1470 - val_accuracy: 0.9284 - val_loss: 0.2164 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9502 - loss: 0.1558
# Epoch 11: val_accuracy did not improve from 0.92845
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.9511 - loss: 0.1447 - val_accuracy: 0.9250 - val_loss: 0.2186 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9549 - loss: 0.1270
# Epoch 12: val_accuracy did not improve from 0.92845
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.9596 - loss: 0.1157 - val_accuracy: 0.9284 - val_loss: 0.2339 - learning_rate: 1.0000e-05
# Score for fold 3: loss of 0.2339; compile_metrics of 92.84%
#
# Training for fold 4 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.5127 - loss: 1.3733
# Epoch 1: val_accuracy improved from None to 0.72232, saving model to inceptionV3_fold_4.keras
#
# Epoch 1: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 117s 734ms/step - accuracy: 0.6319 - loss: 1.0486 - val_accuracy: 0.7223 - val_loss: 0.7976 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7890 - loss: 0.6194
# Epoch 2: val_accuracy improved from 0.72232 to 0.78194, saving model to inceptionV3_fold_4.keras
#
# Epoch 2: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.7962 - loss: 0.5995 - val_accuracy: 0.7819 - val_loss: 0.7663 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8476 - loss: 0.4687
# Epoch 3: val_accuracy improved from 0.78194 to 0.81772, saving model to inceptionV3_fold_4.keras
#
# Epoch 3: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.8455 - loss: 0.4702 - val_accuracy: 0.8177 - val_loss: 0.5736 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8698 - loss: 0.3631
# Epoch 4: val_accuracy improved from 0.81772 to 0.87394, saving model to inceptionV3_fold_4.keras
#
# Epoch 4: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.8779 - loss: 0.3484 - val_accuracy: 0.8739 - val_loss: 0.4128 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9025 - loss: 0.2725
# Epoch 5: val_accuracy improved from 0.87394 to 0.89949, saving model to inceptionV3_fold_4.keras
#
# Epoch 5: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - accuracy: 0.8957 - loss: 0.2944 - val_accuracy: 0.8995 - val_loss: 0.4035 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9166 - loss: 0.2506
# Epoch 6: val_accuracy did not improve from 0.89949
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 178ms/step - accuracy: 0.9157 - loss: 0.2437 - val_accuracy: 0.8978 - val_loss: 0.3573 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9344 - loss: 0.1893
# Epoch 7: val_accuracy improved from 0.89949 to 0.90119, saving model to inceptionV3_fold_4.keras
#
# Epoch 7: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - accuracy: 0.9230 - loss: 0.2168 - val_accuracy: 0.9012 - val_loss: 0.3531 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9244 - loss: 0.2143
# Epoch 8: val_accuracy improved from 0.90119 to 0.91312, saving model to inceptionV3_fold_4.keras
#
# Epoch 8: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 202ms/step - accuracy: 0.9247 - loss: 0.2040 - val_accuracy: 0.9131 - val_loss: 0.3453 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9365 - loss: 0.1767
# Epoch 9: val_accuracy did not improve from 0.91312
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9421 - loss: 0.1635 - val_accuracy: 0.9063 - val_loss: 0.4273 - learning_rate: 1.0000e-04
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9451 - loss: 0.1695
# Epoch 10: val_accuracy did not improve from 0.91312
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9443 - loss: 0.1546 - val_accuracy: 0.8944 - val_loss: 0.3891 - learning_rate: 1.0000e-04
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9565 - loss: 0.1324
# Epoch 11: val_accuracy did not improve from 0.91312
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9579 - loss: 0.1224 - val_accuracy: 0.9114 - val_loss: 0.3741 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9539 - loss: 0.1355
# Epoch 12: val_accuracy improved from 0.91312 to 0.92164, saving model to inceptionV3_fold_4.keras
#
# Epoch 12: finished saving model to inceptionV3_fold_4.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.9600 - loss: 0.1207 - val_accuracy: 0.9216 - val_loss: 0.3395 - learning_rate: 1.0000e-05
# Score for fold 4: loss of 0.3395; compile_metrics of 92.16%
#
# Training for fold 5 ...
# Epoch 1/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.4997 - loss: 1.3798
# Epoch 1: val_accuracy improved from None to 0.56388, saving model to inceptionV3_fold_5.keras
#
# Epoch 1: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 116s 733ms/step - accuracy: 0.6119 - loss: 1.0694 - val_accuracy: 0.5639 - val_loss: 1.5047 - learning_rate: 1.0000e-04
# Epoch 2/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7804 - loss: 0.6420
# Epoch 2: val_accuracy improved from 0.56388 to 0.64736, saving model to inceptionV3_fold_5.keras
#
# Epoch 2: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.7868 - loss: 0.6456 - val_accuracy: 0.6474 - val_loss: 1.3548 - learning_rate: 1.0000e-04
# Epoch 3/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8382 - loss: 0.4716
# Epoch 3: val_accuracy improved from 0.64736 to 0.85520, saving model to inceptionV3_fold_5.keras
#
# Epoch 3: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8387 - loss: 0.4632 - val_accuracy: 0.8552 - val_loss: 0.4373 - learning_rate: 1.0000e-04
# Epoch 4/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8813 - loss: 0.3465
# Epoch 4: val_accuracy improved from 0.85520 to 0.88416, saving model to inceptionV3_fold_5.keras
#
# Epoch 4: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.8809 - loss: 0.3507 - val_accuracy: 0.8842 - val_loss: 0.3352 - learning_rate: 1.0000e-04
# Epoch 5/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8767 - loss: 0.3218
# Epoch 5: val_accuracy did not improve from 0.88416
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 179ms/step - accuracy: 0.8749 - loss: 0.3419 - val_accuracy: 0.8807 - val_loss: 0.3189 - learning_rate: 1.0000e-04
# Epoch 6/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8965 - loss: 0.2769
# Epoch 6: val_accuracy improved from 0.88416 to 0.91312, saving model to inceptionV3_fold_5.keras
#
# Epoch 6: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - accuracy: 0.9119 - loss: 0.2458 - val_accuracy: 0.9131 - val_loss: 0.2969 - learning_rate: 1.0000e-04
# Epoch 7/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9211 - loss: 0.2300
# Epoch 7: val_accuracy did not improve from 0.91312
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 177ms/step - accuracy: 0.9238 - loss: 0.2336 - val_accuracy: 0.8995 - val_loss: 0.3304 - learning_rate: 1.0000e-04
# Epoch 8/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9161 - loss: 0.2418
# Epoch 8: val_accuracy did not improve from 0.91312
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.9179 - loss: 0.2349 - val_accuracy: 0.8739 - val_loss: 0.4484 - learning_rate: 1.0000e-04
# Epoch 9/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9423 - loss: 0.1625
# Epoch 9: val_accuracy did not improve from 0.91312
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.9485 - loss: 0.1534 - val_accuracy: 0.8995 - val_loss: 0.3459 - learning_rate: 1.0000e-05
# Epoch 10/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9487 - loss: 0.1449
# Epoch 10: val_accuracy improved from 0.91312 to 0.91652, saving model to inceptionV3_fold_5.keras
#
# Epoch 10: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - accuracy: 0.9447 - loss: 0.1537 - val_accuracy: 0.9165 - val_loss: 0.3120 - learning_rate: 1.0000e-05
# Epoch 11/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9482 - loss: 0.1738
# Epoch 11: val_accuracy did not improve from 0.91652
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.9523 - loss: 0.1606 - val_accuracy: 0.9097 - val_loss: 0.2952 - learning_rate: 1.0000e-05
# Epoch 12/12
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9478 - loss: 0.1446
# Epoch 12: val_accuracy improved from 0.91652 to 0.92164, saving model to inceptionV3_fold_5.keras
#
# Epoch 12: finished saving model to inceptionV3_fold_5.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - accuracy: 0.9498 - loss: 0.1446 - val_accuracy: 0.9216 - val_loss: 0.2582 - learning_rate: 1.0000e-05
# Score for fold 5: loss of 0.2582; compile_metrics of 92.16%
#
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.2302 - Accuracy: 92.35%
# > Fold 2 - Loss: 0.3112 - Accuracy: 93.71%
# > Fold 3 - Loss: 0.2339 - Accuracy: 92.84%
# > Fold 4 - Loss: 0.3395 - Accuracy: 92.16%
# > Fold 5 - Loss: 0.2582 - Accuracy: 92.16%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 92.65% (+- 0.59%)
# > Loss: 0.2746
# ------------------------------------------------------------------------

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf

# You can also load a specific fold's best model if you prefer:
model = tf.keras.models.load_model('inceptionV3_fold_2.keras')

# Get model predictions on the test set using the last trained fold model (model_cv)
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate and print the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 580ms/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.89      0.96      0.92        93
#         no_tumor       0.98      0.90      0.94        51
# meningioma_tumor       0.92      0.88      0.90        96
#  pituitary_tumor       0.94      0.97      0.95        87
#
#         accuracy                           0.93       327
#        macro avg       0.93      0.92      0.93       327
#     weighted avg       0.93      0.93      0.93       327

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train','Val'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train','Val'])
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(y_true_classes, y_pred_classes, labels)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(labels)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Brain Tumor Detection System

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

class_labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

def detect_and_display(img_path, model, IMAGE_SIZE=150):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load the image using OpenCV exactly as in training (reads as BGR, [0, 255])
        img = cv2.imread(img_path)
        img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))

        img_array = np.expand_dims(img, axis=0)  # Add batch dimension

        # During training, no preprocessing was applied; EfficientNet handles it internally.
        # So we directly pass the array.
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'no_tumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction (convert BGR to RGB for matplotlib)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/meningioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/no_tumor/image(10).jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
4# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/pituitary_tumor/image.jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
# Example usage
image_path = '/content/gdrive/MyDrive/dataset/Testing/glioma_tumor/image(1).jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
